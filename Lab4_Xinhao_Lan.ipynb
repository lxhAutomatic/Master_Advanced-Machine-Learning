# %% [markdown]
# # Advanced Machine Learning - programming assignment 4
#
# *Due: Friday January 28*

# %% [markdown]
# **Please fill in:**
# * Xinhao Lan (1082620)
# * Huaixi Tang (2631695)

# %% [markdown]
# ### Further instructions:
# * Make sure your code is properly commented.
# * Submit your code in Blackboard using one of your accounts; we will put the grade in Blackboard for the other team member as well.
# * **Make sure to name the submitted file according to your and your collaborators last name.** (`submitter_collaborator.ipynb`)

# %% [markdown]
# ## Implementing the PC algorithm
# In this assignment, you will complete an implementation of the PC algorithm. After that, you will use it to discover causal relations in a data set. Each of these two parts is worth 5 points.

# %% [markdown]
# The PC algorithm will need to keep track of a PDAG. We will represent this PDAG by a numpy array `G` of booleans.
#
# The matrix `G` represents a graph as follows:
# * For all `x`, `G[x,x] == False`
# * `G[x,y] == False` and `G[y,x] == False` means: no edge between x and y
# * `G[x,y] == True` and `G[y,x] == True` means: an undirected edge x&mdash;y
# * `G[x,y] == True` and `G[y,x] == False`means: a directed edge x$\to$y

# %%
import numpy as np
import itertools
import graphviz # Install with: conda install python-graphviz

from AML_assignment4_util import *

# %% [markdown]
# The graphviz can draw graphs to different file formats, or show them directly in the notebook. The function `graph_to_graphviz(G, node_names)` converts a numpy array of the form described above to a graph in graphviz format.

# %%
# Demonstration of graph_to_graphviz:
node_names = ['X', 'Y', 'Z', 'W']
G1 = np.zeros((4,4), dtype=bool)
G1[0,1] = G1[2,1] = True # two directed edges
G1[2,3] = G1[3,2] = True # an undirected edge
d = graph_to_graphviz(G1, node_names)
d # must be final line of code block to be displayed

# %% [markdown]
# Here is a Python class for performing the PC algorithm (when an object of this class is created and its `run` function is called). Add the missing code for phase 2, and implement phases 3 and 4. In the next section, you'll find some test cases to see if your code runs without errors and does what you expect it to.

# %%
class PC_algorithm:
    def __init__(self, independence_tester, verbose=1):
        # verbose can be 0 (silent), 1 (report independences), or 2 (also report dependences)
        self.independence_tester = independence_tester
        self.n = independence_tester.n_observed
        self.node_names = independence_tester.node_names
        self.verbose = verbose
        self.G = np.logical_not(np.eye(self.n, dtype=bool))
        self.sepset = dict()

    def skeleton_search(self):
        # PHASE II: Skeleton search
        # Note: Adj(X) in the slides means: all nodes adjacent to X in the current graph G
        for k in range(self.n - 1):
            for x in range(self.n):
                for y in range(self.n):
                    if not self.G[x,y]:
                        continue
                    # Try all subsets S of Adj(x) \ {y} with |S|=k,
                    # until an independence is found.
                    # Hint: use itertools.combinations

                    # Your code here (1 point)
                    sets = itertools.combinations([i for i in range(self.n) if (i != x and i != y)], k)

                    for S in sets: # replace this line by your code
                        indep = self.independence_tester.test_independence(x, y, S)
                        if indep:
                            if self.verbose >= 1:
                                print("independence found: {0} and {1} given {{{2}}}"
                                      .format(self.node_names[x], self.node_names[y],
                                              ", ".join([self.node_names[v] for v in S])))
                            # Remove this edge.
                            self.G[x,y] = self.G[y,x] = False
                            # We use frozensets as keys in the dictionary self.sepset,
                            # because ordinary sets can't be used as keys to dictionaries.
                            # self.sepset[frozenset([x,y])] = S
                            S_new = np.zeros(self.n, dtype=bool)
                            np.put(S_new, S, True)
                            self.sepset[frozenset([x,y])] = S_new
                            break
                        else:
                            if self.verbose >= 2:
                                print("dependence found: {0} and {1} given {{{2}}}"
                                      .format(self.node_names[x], self.node_names[y],
                                              ", ".join([self.node_names[v] for v in S])))

            # Do we need to continue with larger k?
            max_S_size = np.sum(self.G, axis=0) - 1
            if np.all(max_S_size < k + 1):
                break
        return

    def orient_v_structures(self):
        # PHASE III: Orient v-structures
        # Something to watch out for:
        # If the data are not faithful to any graph, the algorithm may end up trying
        # to orient a single edge in two different ways. You can choose either
        # orientation if this happens. But make sure not to accidentally delete such an edge!

        # Your code here (2 points)
        not_adj_pairs = []
        for r, row in enumerate(self.G):
          for c, column in enumerate(row):
            if (self.G[r][c] == False and not ([c,r] in not_adj_pairs) and not c==r):
              not_adj_pairs.append([r,c])

        common_adjs = []
        for pair in not_adj_pairs:
          common_adj = []
          for r, row in enumerate(self.G):
            if (r!=pair[0] and r!=pair[1] and ((self.G[r,pair[0]] and self.G[r,pair[1]]))):
              common_adj.append(r)
          common_adjs.append(common_adj)

        for i,pair in enumerate(not_adj_pairs):
          z = common_adjs[i]
          for z_real in z:
            if (not(self.sepset[frozenset(pair)][z_real])):
              self.G[pair[0],z_real] = True
              self.G[z_real, pair[0]] = False
              self.G[pair[1],z_real] = True
              self.G[z_real, pair[1]] = False
              break
        return

    def orientation_rules(self):
        # PHASE IV: Orientation rules

        # Your code here (2 points)
        applied = True
        while applied:
          applied = False
          for i in range(self.n):
            for j in range(self.n):
              if (j != i) :
                for l in range(self.n):
                  if (l!= i and l!=j):
                    for k in range(self.n):
                      if (k!=l and k!= i and k!=j and self.G[i][j] and (self.G[j][i]) and self.G[l][j] and not(self.G[j][l]) and self.G[k][j] and not(self.G[j][k]) and self.G[i][l] and self.G[l][i] and self.G[i][k] and self.G[k][i] and not(self.G[l][k]) and not(self.G[k][l])):
                        self.G[j][i] = False
                        applied = True
                    if (self.G[i][j] and not(self.G[j][i]) and self.G[j][l] and not(self.G[l][j]) and self.G[i][l] and self.G[l][i]):
                      self.G[l][i] = False
                      applied = True
                    if (self.G[i][j] and not(self.G[j][i]) and self.G[j][l] and (self.G[l][j]) and not(self.G[i][l]) and not(self.G[l][i])):
                      self.G[l][j] = False
                      applied = True
        return

    def run(self):
        # The initialization step has already been performed by the __init__ method.
        # Perform the other phases one by one. Each of the following functions
        # modifies self.G, which represents the graph.
        self.skeleton_search()
        self.orient_v_structures()
        self.orientation_rules()

        return self.G

# %% [markdown]
# ## Testing the PC implementation
#
# To verify that the algorithm is working correctly, we will feed it output from an *oracle* instead of conditional independence test results from a data set. The oracle knows what the true graph is, and mimics the conditional independence test results that we would get for data that is Markov and faithful to that graph. In this situation, the PC algorithm will recover the Markov equivalence class of the true graph.

# %%
class IndependenceOracle:
    def __init__(self, true_G, node_names, n_observed=None):
        self.G = true_G
        self.n = true_G.shape[0]
        self.n_observed = n_observed if n_observed is not None else self.n
        self.node_names = node_names
    def test_independence(self, x, y, S):
        S_mask = np.zeros(self.n, dtype=bool)
        np.put(S_mask, S, True)
        return is_d_separated(self.G, x, y, S_mask)

# %% [markdown]
# We will compare the output of PC to the oracle's true graph for the graph `G1` we saw before, and for several other graphs. (You can add more tests to help chase down any bugs.)

# %%
oracle = IndependenceOracle(G1, node_names)
A = PC_algorithm(oracle, verbose=2)
G = A.run()
print("PASS" if np.all(G == G1) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# dependence found: X and Y given {}
# independence found: X and Z given {}
# independence found: X and W given {}
# dependence found: Y and X given {}
# dependence found: Y and Z given {}
# dependence found: Y and W given {}
# dependence found: Z and Y given {}
# dependence found: Z and W given {}
# dependence found: W and Y given {}
# dependence found: W and Z given {}
# dependence found: X and Y given {Z}
# dependence found: X and Y given {W}
# dependence found: Y and X given {Z}
# dependence found: Y and X given {W}
# dependence found: Y and Z given {X}
# dependence found: Y and Z given {W}
# dependence found: Y and W given {X}
# independence found: Y and W given {Z}
# dependence found: Z and Y given {X}
# dependence found: Z and Y given {W}
# dependence found: Z and W given {X}
# dependence found: Z and W given {Y}
# dependence found: W and Z given {X}
# dependence found: W and Z given {Y}
# PASS

# %%
G2 = np.zeros((4,4), dtype=bool)
G2[0,2] = G2[1,2] = G2[2,3] = True
graph_to_graphviz(G2, node_names)

# %%
oracle = IndependenceOracle(G2, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G2) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# independence found: X and Y given {}
# independence found: X and W given {Z}
# independence found: Y and W given {Z}
# PASS

# %%
G3 = np.zeros((4,4), dtype=bool)
G3[0,2] = G3[1,2] = G3[1,3] = G3[2,3] = True
graph_to_graphviz(G3, node_names)

# %%
oracle = IndependenceOracle(G3, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G3) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# independence found: X and Y given {}
# independence found: X and W given {Y, Z}
# PASS

# %%
G4 = np.logical_not(np.eye(4, dtype=bool))
G4[0,1] = G4[1,0] = False
G4[3,0] = G4[3,1] = G4[3,2] = False
graph_to_graphviz(G4, node_names)

# %%
oracle = IndependenceOracle(G4, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G4) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# independence found: X and Y given {Z}
# PASS

# %%
# Example of a case for which no DAG exists that is Markov and faithful to the distribution.
# L is a latent variable that the PC algorithm won't know about. PC's output should be either
# X --> Y --> Z <-- W or
# X --> Y <-- Z <-- W.
# If there is no edge between Y and Z in your output, this most likely indicates a bug in
# your implementation of phase III.
G5 = np.zeros((5,5), dtype=bool)
G5[0,1] = G5[4,1] = True
G5[3,2] = G5[4,2] = True
graph_to_graphviz(G5, ['X', 'Y', 'Z', 'W', 'L'])

# %%
oracle = IndependenceOracle(G5, node_names, n_observed = 4)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if G[0,1] and G[3,2] and (G[1,2] or G[2,1]) and np.sum(G) == 3 else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# independence found: X and Z given {}
# independence found: X and W given {}
# independence found: Y and W given {}
# PASS

# %% [markdown]
# ## Running PC on data
# In this second part of the assignment, you will apply the PC algorithm to the biological dataset of Sachs et al. (2005). In this dataset, the columns represent 11 different proteins, which were measured in thousands of human immune system cells. Each row is a single cell. The cells were prepared in different ways, by adding different chemicals some time before the measurements were made. A twelfth column, labeled `experiment`, indicates in which way that cell was prepared. We can think of `experiment=1` as denoting the observational data, and other values of `experiment` (2 through 14) as various interventional datasets.

# %%
import pandas as pd

all_data = pd.read_csv("sachs2005_combined.csv", sep='\t')
# Transform all columns except 'experiment' by taking the logarithm of 10 + the original value
all_data.loc[:, all_data.columns != 'experiment'] = np.log(10 + all_data.loc[:, all_data.columns != 'experiment'])

# %% [markdown]
# We will apply the PC algorithm to just the observational data.
#
# Make a new dataframe containing only the data where experiment equals 1. Remove the `experiment` column from this dataframe. Check the shape of your dataframe: it should be `(853, 11)`.

# %%
exp1 = all_data.copy()

# Get names of indexes for which column experiemnt has not value 1
indexNames = exp1[ exp1['experiment'] != 1 ].index

# Delete these row indexes from dataFrame
exp1.drop(indexNames , inplace=True)

# dropping experiment column
exp1.drop(["experiment"], axis = 1, inplace = True)

exp1.shape
exp1
# Out:
#          praf      pmek      plcg  ...       PKC       P38      pjnk
# 0    3.594569  3.144152  2.934920  ...  3.295837  4.005513  3.912023
# 1    3.826465  3.277145  3.104587  ...  2.593013  3.277145  4.269697
# 2    4.239887  3.990834  3.202746  ...  3.063391  3.735286  3.384390
# 3    4.418841  4.530447  3.499533  ...  3.165475  3.653252  3.499533
# 4    3.777348  3.394508  2.720637  ...  2.685123  3.575151  4.514151
# ..        ...       ...       ...  ...       ...       ...       ...
# 848  3.955082  3.627004  3.449988  ...  3.462606  3.681351  2.905808
# 849  4.278054  3.456317  2.973487  ...  3.086487  3.817712  4.109233
# 850  4.727388  3.742420  3.005683  ...  3.198673  3.493473  2.723267
# 851  4.473922  3.517498  3.549617  ...  3.742420  4.537961  3.613617
# 852  4.036009  3.218876  2.918311  ...  3.430756  3.845883  2.978077
#
# [853 rows x 11 columns]

# %% [markdown]
# For the next part, you will need to install the package [tigramite](https://github.com/jakobrunge/tigramite). Here are three different ways in which you might be able to install it, in the order in which we recommend you to try them:
#
# 1. `conda install -c egilliesix tigramite`
#
# 2. `conda install git pip`
# `pip install git+git://github.com/jakobrunge/tigramite.git`
#
# 3. If not in a conda environment, follow the README on github.
#
# To run the PC algorithm on data, we need to perform (conditional) independence tests. Tigramite implements several such tests. The simplest of these tests is `ParCorr()`. It assumes the data come from a linear structural causal model, which they actually don't. We will use it anyway, because the alternatives (such as `CMIknn()` (Runge, 2018)) are more effort to install and orders of magnitude slower, while `ParCorr()` usually already gives decent results.
#
# As a statistical test, a conditional independence test works by computing a p-value. If a conditional independence exists, this p-value will be approximately uniformly distributed on the interval between 0 and 1. If the variables being tested are conditionally dependent, the p-value will be close to 0. PC wants to know a binary answer, so we will pick some threshold alpha and declare an independence if the p-value is larger than alpha.
#
# In statistical testing, alpha is often taken to be 0.05 or smaller. For PC, it may be more appropriate to pick a larger alpha instead. This is because as soon as PC finds a (conditional) independence between two variables, it will delete the edge between them and do no more tests between those two variables. If this happens while it shouldn't have, PC can't put the edge back. But in the reverse situation, if PC leaves an edge in place while it should have deleted it, there is still a possibility that the edge will be deleted later, when another test between those two variables reports a more convincing independence.

# %%
# !pip install git+git://github.com/jakobrunge/tigramite.git
# Out:
# Collecting git+git://github.com/jakobrunge/tigramite.git
#   Cloning git://github.com/jakobrunge/tigramite.git to /tmp/pip-req-build-mwn9ien8
#   Running command git clone -q git://github.com/jakobrunge/tigramite.git /tmp/pip-req-build-mwn9ien8
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tigramite==4.2.2.1) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from tigramite==4.2.2.1) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tigramite==4.2.2.1) (1.15.0)

# %%
from tigramite.independence_tests import ParCorr#, CMIknn
import tigramite.data_processing as pp
# Importing these may give some warnings (e.g. 'Could not import r-package RCIT'),
# but most of these warnings can be ignored because we are not using the mentioned packages.

class IndependenceTester:
    def __init__(self, data, cond_ind_test, alpha, verbose=2, n_observed=None):
        # data: a pandas dataframe
        # cond_ind_test: an independence test from tigramite, e.g. ParCorr()
        # alpha: the significance level to which the p-values are compared

        # tigramite uses its own kind of dataframe, so convert the data to that format
        df_tigramite = pp.DataFrame(data.to_numpy(), var_names=data.columns)
        self.cond_ind_test = cond_ind_test
        self.cond_ind_test.set_dataframe(df_tigramite)
        self.n = data.shape[1]
        self.n_observed = n_observed if n_observed is not None else self.n
        self.verbose = verbose
        self.node_names = data.columns
        self.alpha = alpha
    def test_independence(self, x, y, S):
        val, pval = self.cond_ind_test.run_test(X=[(x, 0)],
                                                Y=[(y, 0)],
                                                Z=[(z, 0) for z in S])
        test_result = pval > self.alpha
        if self.verbose >= 2 or (self.verbose >= 1 and test_result):
            print("test: {0} and {1} given {2} -> pval={3}".format(self.node_names[x], self.node_names[y],
                                                                   ", ".join([self.node_names[v] for v in S]),
                                                                   pval))
        return test_result
# Out:
# /usr/local/lib/python3.7/dist-packages/tigramite/independence_tests/gpdc.py:16: UserWarning: No module named 'dcor'
#   warnings.warn(str(e))
# /usr/local/lib/python3.7/dist-packages/tigramite/independence_tests/gpdc_torch.py:18: UserWarning: No module named 'dcor'
#   warnings.warn(str(e))

# %% [markdown]
# Using an IndependenceTester object (which works similarly to the IndependenceOracle we used earlier), run the PC algorithm on the observational data. Display the graph that comes out. You may experiment with different values of alpha; the graph you get should either be connected (i.e. consist of one connected component), or have just two connected components.

# %%
# Your code here (1 point)
tester = IndependenceTester(exp1, ParCorr(), 0.4)
A = PC_algorithm(tester)
G = A.run()
graph_to_graphviz(G, tester.node_names)
# Out:
# test: praf and pmek given  -> pval=6.283143797791793e-129
# test: praf and plcg given  -> pval=0.5373868874563719
# independence found: praf and plcg given {}
# test: praf and PIP2 given  -> pval=0.972791929704881
# independence found: praf and PIP2 given {}
# test: praf and PIP3 given  -> pval=0.3346593897889285
# test: praf and perk given  -> pval=0.6217936401751427
# independence found: praf and perk given {}
# test: praf and pakts473 given  -> pval=0.3213233858427679
# test: praf and PKA given  -> pval=0.9668029258427129
# independence found: praf and PKA given {}
# test: praf and PKC given  -> pval=0.20877767649396428
# test: praf and P38 given  -> pval=0.09366579153448505
# test: praf and pjnk given  -> pval=0.5819563650509856
# independence found: praf and pjnk given {}
# test: pmek and praf given  -> pval=6.283143797791793e-129
# test: pmek and plcg given  -> pval=0.8066845247629106
# independence found: pmek and plcg given {}
# test: pmek and PIP2 given  -> pval=0.2629515450360251
# test: pmek and PIP3 given  -> pval=0.047159853623461395
# test: pmek and perk given  -> pval=0.5704656795447965
# independence found: pmek and perk given {}
# test: pmek and pakts473 given  -> pval=0.6961447497712376
# independence found: pmek and pakts473 given {}
# test: pmek and PKA given  -> pval=0.8780133772321389
# independence found: pmek and PKA given {}
# test: pmek and PKC given  -> pval=0.24548793643262426
# test: pmek and P38 given  -> pval=0.2108968367630373
# test: pmek and pjnk given  -> pval=0.21503599041809196
# test: plcg and PIP2 given  -> pval=0.014760116617122933
# test: plcg and PIP3 given  -> pval=0.0001086244058075753
# test: plcg and perk given  -> pval=0.29940931183764
# test: plcg and pakts473 given  -> pval=0.43600892878968867
# independence found: plcg and pakts473 given {}
# test: plcg and PKA given  -> pval=0.6791534824965261
# independence found: plcg and PKA given {}
# test: plcg and PKC given  -> pval=0.7514732463603042
# independence found: plcg and PKC given {}
# test: plcg and P38 given  -> pval=0.9884312693084769
# independence found: plcg and P38 given {}
# test: plcg and pjnk given  -> pval=0.08191083255848276
# test: PIP2 and pmek given  -> pval=0.2629515450360251
# test: PIP2 and plcg given  -> pval=0.014760116617122933
# test: PIP2 and PIP3 given  -> pval=6.64072468868195e-31
# test: PIP2 and perk given  -> pval=0.2567905663208524
# test: PIP2 and pakts473 given  -> pval=0.6414570791003118
# independence found: PIP2 and pakts473 given {}
# test: PIP2 and PKA given  -> pval=0.4541744146187495
# independence found: PIP2 and PKA given {}
# test: PIP2 and PKC given  -> pval=0.5810493328129228
# independence found: PIP2 and PKC given {}
# test: PIP2 and P38 given  -> pval=0.8394313692867976
# independence found: PIP2 and P38 given {}
# test: PIP2 and pjnk given  -> pval=0.8359516510501772
# independence found: PIP2 and pjnk given {}
# test: PIP3 and praf given  -> pval=0.3346593897889285
# test: PIP3 and pmek given  -> pval=0.047159853623461395
# test: PIP3 and plcg given  -> pval=0.0001086244058075753
# test: PIP3 and PIP2 given  -> pval=6.64072468868195e-31
# test: PIP3 and perk given  -> pval=0.26600053639646826
# test: PIP3 and pakts473 given  -> pval=0.24197169954142803
# test: PIP3 and PKA given  -> pval=0.9987535723897432
# independence found: PIP3 and PKA given {}
# test: PIP3 and PKC given  -> pval=0.6744562666085027
# independence found: PIP3 and PKC given {}
# test: PIP3 and P38 given  -> pval=0.9038552784559979
# independence found: PIP3 and P38 given {}
# test: PIP3 and pjnk given  -> pval=0.4790215629173281
# independence found: PIP3 and pjnk given {}
# test: perk and plcg given  -> pval=0.29940931183764
# test: perk and PIP2 given  -> pval=0.2567905663208524
# test: perk and PIP3 given  -> pval=0.26600053639646826
# test: perk and pakts473 given  -> pval=1.7027177448400614e-264
# test: perk and PKA given  -> pval=7.112938819178581e-27
# test: perk and PKC given  -> pval=0.6181218753841424
# independence found: perk and PKC given {}
# test: perk and P38 given  -> pval=0.503830635150357
# independence found: perk and P38 given {}
# test: perk and pjnk given  -> pval=0.3219670925204471
# test: pakts473 and praf given  -> pval=0.3213233858427679
# test: pakts473 and PIP3 given  -> pval=0.24197169954142803
# test: pakts473 and perk given  -> pval=1.7027177448400614e-264
# test: pakts473 and PKA given  -> pval=1.7181586613458174e-38
# test: pakts473 and PKC given  -> pval=0.4382659417249428
# independence found: pakts473 and PKC given {}
# test: pakts473 and P38 given  -> pval=0.9757079496959222
# independence found: pakts473 and P38 given {}
# test: pakts473 and pjnk given  -> pval=0.5651487944612898
# independence found: pakts473 and pjnk given {}
# test: PKA and perk given  -> pval=7.112938819178581e-27
# test: PKA and pakts473 given  -> pval=1.7181586613458174e-38
# test: PKA and PKC given  -> pval=0.2720205079127226
# test: PKA and P38 given  -> pval=0.4308722466820034
# independence found: PKA and P38 given {}
# test: PKA and pjnk given  -> pval=0.33883752654591903
# test: PKC and praf given  -> pval=0.20877767649396428
# test: PKC and pmek given  -> pval=0.24548793643262426
# test: PKC and PKA given  -> pval=0.2720205079127226
# test: PKC and P38 given  -> pval=8.847651325236589e-116
# test: PKC and pjnk given  -> pval=2.1669122412805705e-15
# test: P38 and praf given  -> pval=0.09366579153448505
# test: P38 and pmek given  -> pval=0.2108968367630373
# test: P38 and PKC given  -> pval=8.847651325236589e-116
# test: P38 and pjnk given  -> pval=0.014289554530539456
# test: pjnk and pmek given  -> pval=0.21503599041809196
# test: pjnk and plcg given  -> pval=0.08191083255848276
# test: pjnk and perk given  -> pval=0.3219670925204471
# test: pjnk and PKA given  -> pval=0.33883752654591903
# test: pjnk and PKC given  -> pval=2.1669122412805705e-15
# test: pjnk and P38 given  -> pval=0.014289554530539456
# test: praf and pmek given plcg -> pval=8.807937771797896e-129
# test: praf and pmek given PIP2 -> pval=5.030183766210991e-129
# test: praf and pmek given PIP3 -> pval=1.1710532967616427e-128
# test: praf and pmek given perk -> pval=4.52616071229818e-129
# test: praf and pmek given pakts473 -> pval=8.700646286905379e-129
# test: praf and pmek given PKA -> pval=8.828512233774518e-129
# test: praf and pmek given PKC -> pval=1.6129702798226958e-128
# test: praf and pmek given P38 -> pval=1.9291969694040297e-128
# test: praf and pmek given pjnk -> pval=1.3645391235360691e-129
# test: praf and PIP3 given pmek -> pval=0.5415157306019437
# independence found: praf and PIP3 given {pmek}
# test: praf and pakts473 given pmek -> pval=0.31285775524258064
# test: praf and pakts473 given plcg -> pval=0.3133498037270152
# test: praf and pakts473 given PIP2 -> pval=0.3212801122523325
# test: praf and pakts473 given PIP3 -> pval=0.3402067188235216
# test: praf and pakts473 given perk -> pval=0.25323299164482055
# test: praf and pakts473 given PKA -> pval=0.28244277833103126
# test: praf and pakts473 given PKC -> pval=0.3375620353022756
# test: praf and pakts473 given P38 -> pval=0.31995447437388863
# test: praf and pakts473 given pjnk -> pval=0.3267579555996144
# test: praf and PKC given pmek -> pval=0.5366080583202169
# independence found: praf and PKC given {pmek}
# test: praf and P38 given pmek -> pval=0.2629169015855697
# test: praf and P38 given plcg -> pval=0.09384553974544577
# test: praf and P38 given PIP2 -> pval=0.09380422003622749
# test: praf and P38 given PIP3 -> pval=0.09289476046967415
# test: praf and P38 given perk -> pval=0.09152714601129876
# test: praf and P38 given pakts473 -> pval=0.09346560946832527
# test: praf and P38 given PKA -> pval=0.0939594561076349
# test: praf and P38 given PKC -> pval=0.26239837764141366
# test: praf and P38 given pjnk -> pval=0.10200778117681907
# test: pmek and praf given plcg -> pval=8.807937771797896e-129
# test: pmek and praf given PIP2 -> pval=5.030183766210991e-129
# test: pmek and praf given PIP3 -> pval=1.1710532967616427e-128
# test: pmek and praf given perk -> pval=4.52616071229818e-129
# test: pmek and praf given pakts473 -> pval=8.700646286905379e-129
# test: pmek and praf given PKA -> pval=8.828512233774518e-129
# test: pmek and praf given PKC -> pval=1.6129702798226958e-128
# test: pmek and praf given P38 -> pval=1.9291969694040297e-128
# test: pmek and praf given pjnk -> pval=1.3645391235360691e-129
# test: pmek and PIP2 given praf -> pval=0.12275646135104432
# test: pmek and PIP2 given plcg -> pval=0.27035819498517893
# test: pmek and PIP2 given PIP3 -> pval=0.6939699890159092
# independence found: pmek and PIP2 given {PIP3}
# test: pmek and PIP3 given praf -> pval=0.06606848342058752
# test: pmek and PIP3 given plcg -> pval=0.04899460255452561
# test: pmek and PIP3 given PIP2 -> pval=0.09204798920888208
# test: pmek and PIP3 given perk -> pval=0.044725042243271104
# test: pmek and PIP3 given pakts473 -> pval=0.04886664701358693
# test: pmek and PIP3 given PKA -> pval=0.04728775028331408
# test: pmek and PIP3 given PKC -> pval=0.04525655814663446
# test: pmek and PIP3 given P38 -> pval=0.046509307985409046
# test: pmek and PIP3 given pjnk -> pval=0.04377072336274767
# test: pmek and PKC given praf -> pval=0.6975313698322559
# independence found: pmek and PKC given {praf}
# test: pmek and P38 given praf -> pval=0.9209805816737114
# independence found: pmek and P38 given {praf}
# test: pmek and pjnk given praf -> pval=0.02169383910495845
# test: pmek and pjnk given plcg -> pval=0.2091225264927847
# test: pmek and pjnk given PIP2 -> pval=0.21202730912771614
# test: pmek and pjnk given PIP3 -> pval=0.1968318951491581
# test: pmek and pjnk given perk -> pval=0.22217421279884172
# test: pmek and pjnk given pakts473 -> pval=0.21233539852670025
# test: pmek and pjnk given PKA -> pval=0.21319399665221642
# test: pmek and pjnk given PKC -> pval=0.10757752389893874
# test: pmek and pjnk given P38 -> pval=0.17699477989162737
# test: plcg and PIP2 given praf -> pval=0.014825988893488126
# test: plcg and PIP2 given pmek -> pval=0.015131096601754527
# test: plcg and PIP2 given PIP3 -> pval=0.29258985548950495
# test: plcg and PIP2 given perk -> pval=0.016412416150011305
# test: plcg and PIP2 given pakts473 -> pval=0.015288839711199051
# test: plcg and PIP2 given PKA -> pval=0.014345352358251948
# test: plcg and PIP2 given PKC -> pval=0.015043142012578297
# test: plcg and PIP2 given P38 -> pval=0.01481219120100945
# test: plcg and PIP2 given pjnk -> pval=0.015150006722995806
# test: plcg and PIP3 given praf -> pval=0.00011785949933376413
# test: plcg and PIP3 given pmek -> pval=0.00011315638959954396
# test: plcg and PIP3 given PIP2 -> pval=0.0014566026634638637
# test: plcg and PIP3 given perk -> pval=9.092045886704982e-05
# test: plcg and PIP3 given pakts473 -> pval=9.445742164893531e-05
# test: plcg and PIP3 given PKA -> pval=0.00010947687114614962
# test: plcg and PIP3 given PKC -> pval=0.00010730469922934593
# test: plcg and PIP3 given P38 -> pval=0.00010960052315181566
# test: plcg and PIP3 given pjnk -> pval=0.00012633591292423468
# test: plcg and perk given praf -> pval=0.294680068982864
# test: plcg and perk given pmek -> pval=0.30180951831702735
# test: plcg and perk given PIP2 -> pval=0.343907218852028
# test: plcg and perk given PIP3 -> pval=0.23191510826775544
# test: plcg and perk given pakts473 -> pval=0.46513468640174194
# independence found: plcg and perk given {pakts473}
# test: plcg and pjnk given praf -> pval=0.08403978095703178
# test: plcg and pjnk given pmek -> pval=0.07998930143328802
# test: plcg and pjnk given PIP2 -> pval=0.08408776650246755
# test: plcg and pjnk given PIP3 -> pval=0.09690573141277124
# test: plcg and pjnk given perk -> pval=0.07571167455199716
# test: plcg and pjnk given pakts473 -> pval=0.07925198567886454
# test: plcg and pjnk given PKA -> pval=0.0843120687342489
# test: plcg and pjnk given PKC -> pval=0.08607478701167394
# test: plcg and pjnk given P38 -> pval=0.08122603934659407
# test: PIP2 and plcg given praf -> pval=0.014825988893488126
# test: PIP2 and plcg given pmek -> pval=0.015131096601754527
# test: PIP2 and plcg given PIP3 -> pval=0.29258985548950495
# test: PIP2 and plcg given perk -> pval=0.016412416150011305
# test: PIP2 and plcg given pakts473 -> pval=0.015288839711199051
# test: PIP2 and plcg given PKA -> pval=0.014345352358251948
# test: PIP2 and plcg given PKC -> pval=0.015043142012578297
# test: PIP2 and plcg given P38 -> pval=0.01481219120100945
# test: PIP2 and plcg given pjnk -> pval=0.015150006722995806
# test: PIP2 and PIP3 given praf -> pval=6.735049035658879e-31
# test: PIP2 and PIP3 given pmek -> pval=1.2489055624816719e-30
# test: PIP2 and PIP3 given plcg -> pval=8.19129767724439e-30
# test: PIP2 and PIP3 given perk -> pval=3.276479447582334e-31
# test: PIP2 and PIP3 given pakts473 -> pval=4.909571721783081e-31
# test: PIP2 and PIP3 given PKA -> pval=6.847343734407327e-31
# test: PIP2 and PIP3 given PKC -> pval=6.2152735604000875e-31
# test: PIP2 and PIP3 given P38 -> pval=7.232426182230629e-31
# test: PIP2 and PIP3 given pjnk -> pval=7.32725056164309e-31
# test: PIP2 and perk given praf -> pval=0.25675974829424886
# test: PIP2 and perk given pmek -> pval=0.2658831421286741
# test: PIP2 and perk given plcg -> pval=0.29323255737626114
# test: PIP2 and perk given PIP3 -> pval=0.09170710043886576
# test: PIP2 and perk given pakts473 -> pval=0.13866455734720934
# test: PIP2 and perk given PKA -> pval=0.3534112662515406
# test: PIP2 and perk given PKC -> pval=0.2529756840442085
# test: PIP2 and perk given P38 -> pval=0.2549886986300954
# test: PIP2 and perk given pjnk -> pval=0.2538432801037415
# test: PIP3 and pmek given praf -> pval=0.06606848342058752
# test: PIP3 and pmek given plcg -> pval=0.04899460255452561
# test: PIP3 and pmek given PIP2 -> pval=0.09204798920888208
# test: PIP3 and pmek given perk -> pval=0.044725042243271104
# test: PIP3 and pmek given pakts473 -> pval=0.04886664701358693
# test: PIP3 and pmek given PKA -> pval=0.04728775028331408
# test: PIP3 and pmek given PKC -> pval=0.04525655814663446
# test: PIP3 and pmek given P38 -> pval=0.046509307985409046
# test: PIP3 and pmek given pjnk -> pval=0.04377072336274767
# test: PIP3 and plcg given praf -> pval=0.00011785949933376413
# test: PIP3 and plcg given pmek -> pval=0.00011315638959954396
# test: PIP3 and plcg given PIP2 -> pval=0.0014566026634638637
# test: PIP3 and plcg given perk -> pval=9.092045886704982e-05
# test: PIP3 and plcg given pakts473 -> pval=9.445742164893531e-05
# test: PIP3 and plcg given PKA -> pval=0.00010947687114614962
# test: PIP3 and plcg given PKC -> pval=0.00010730469922934593
# test: PIP3 and plcg given P38 -> pval=0.00010960052315181566
# test: PIP3 and plcg given pjnk -> pval=0.00012633591292423468
# test: PIP3 and PIP2 given praf -> pval=6.735049035658879e-31
# test: PIP3 and PIP2 given pmek -> pval=1.2489055624816719e-30
# test: PIP3 and PIP2 given plcg -> pval=8.19129767724439e-30
# test: PIP3 and PIP2 given perk -> pval=3.276479447582334e-31
# test: PIP3 and PIP2 given pakts473 -> pval=4.909571721783081e-31
# test: PIP3 and PIP2 given PKA -> pval=6.847343734407327e-31
# test: PIP3 and PIP2 given PKC -> pval=6.2152735604000875e-31
# test: PIP3 and PIP2 given P38 -> pval=7.232426182230629e-31
# test: PIP3 and PIP2 given pjnk -> pval=7.32725056164309e-31
# test: PIP3 and perk given praf -> pval=0.27303455219617545
# test: PIP3 and perk given pmek -> pval=0.24885242619091652
# test: PIP3 and perk given plcg -> pval=0.20742312167501883
# test: PIP3 and perk given PIP2 -> pval=0.09453013332191126
# test: PIP3 and perk given pakts473 -> pval=0.8491069994142185
# independence found: PIP3 and perk given {pakts473}
# test: PIP3 and pakts473 given praf -> pval=0.25518050766295985
# test: PIP3 and pakts473 given pmek -> pval=0.25197057823226354
# test: PIP3 and pakts473 given plcg -> pval=0.19910971877272246
# test: PIP3 and pakts473 given PIP2 -> pval=0.14498828778279532
# test: PIP3 and pakts473 given perk -> pval=0.6820232059042046
# independence found: PIP3 and pakts473 given {perk}
# test: perk and PIP2 given praf -> pval=0.25675974829424886
# test: perk and PIP2 given pmek -> pval=0.2658831421286741
# test: perk and PIP2 given plcg -> pval=0.29323255737626114
# test: perk and PIP2 given PIP3 -> pval=0.09170710043886576
# test: perk and PIP2 given pakts473 -> pval=0.13866455734720934
# test: perk and PIP2 given PKA -> pval=0.3534112662515406
# test: perk and PIP2 given PKC -> pval=0.2529756840442085
# test: perk and PIP2 given P38 -> pval=0.2549886986300954
# test: perk and PIP2 given pjnk -> pval=0.2538432801037415
# test: perk and pakts473 given praf -> pval=2.947002243253168e-264
# test: perk and pakts473 given pmek -> pval=7.395997135565909e-265
# test: perk and pakts473 given plcg -> pval=4.5436009774965945e-264
# test: perk and pakts473 given PIP2 -> pval=2.198714754087709e-264
# test: perk and pakts473 given PIP3 -> pval=6.3142873409324034e-264
# test: perk and pakts473 given PKA -> pval=2.468083358340046e-239
# test: perk and pakts473 given PKC -> pval=3.6780630616033725e-264
# test: perk and pakts473 given P38 -> pval=1.8469503526442663e-264
# test: perk and pakts473 given pjnk -> pval=3.4467864918014823e-264
# test: perk and PKA given praf -> pval=7.54390685357959e-27
# test: perk and PKA given pmek -> pval=7.164954037055708e-27
# test: perk and PKA given plcg -> pval=5.826226697211581e-27
# test: perk and PKA given PIP2 -> pval=9.427969733719193e-27
# test: perk and PKA given PIP3 -> pval=6.961977661643675e-27
# test: perk and PKA given pakts473 -> pval=0.39378726952547793
# test: perk and PKA given PKC -> pval=8.57369036293957e-27
# test: perk and PKA given P38 -> pval=5.671912252992131e-27
# test: perk and PKA given pjnk -> pval=9.781040446619927e-27
# test: perk and pjnk given praf -> pval=0.32667017229147344
# test: perk and pjnk given pmek -> pval=0.3336519525588004
# test: perk and pjnk given plcg -> pval=0.29177682807612065
# test: perk and pjnk given PIP2 -> pval=0.3179532510239752
# test: perk and pjnk given PIP3 -> pval=0.33512914705589014
# test: perk and pjnk given pakts473 -> pval=0.31980042015814836
# test: perk and pjnk given PKA -> pval=0.486801944361941
# independence found: perk and pjnk given {PKA}
# test: pakts473 and praf given pmek -> pval=0.31285775524258064
# test: pakts473 and praf given plcg -> pval=0.3133498037270152
# test: pakts473 and praf given PIP2 -> pval=0.3212801122523325
# test: pakts473 and praf given PIP3 -> pval=0.3402067188235216
# test: pakts473 and praf given perk -> pval=0.25323299164482055
# test: pakts473 and praf given PKA -> pval=0.28244277833103126
# test: pakts473 and praf given PKC -> pval=0.3375620353022756
# test: pakts473 and praf given P38 -> pval=0.31995447437388863
# test: pakts473 and praf given pjnk -> pval=0.3267579555996144
# test: pakts473 and perk given praf -> pval=2.947002243253168e-264
# test: pakts473 and perk given pmek -> pval=7.395997135565909e-265
# test: pakts473 and perk given plcg -> pval=4.5436009774965945e-264
# test: pakts473 and perk given PIP2 -> pval=2.198714754087709e-264
# test: pakts473 and perk given PIP3 -> pval=6.3142873409324034e-264
# test: pakts473 and perk given PKA -> pval=2.468083358340046e-239
# test: pakts473 and perk given PKC -> pval=3.6780630616033725e-264
# test: pakts473 and perk given P38 -> pval=1.8469503526442663e-264
# test: pakts473 and perk given pjnk -> pval=3.4467864918014823e-264
# test: pakts473 and PKA given praf -> pval=1.7399024829647947e-38
# test: pakts473 and PKA given pmek -> pval=1.9204063398399243e-38
# test: pakts473 and PKA given plcg -> pval=1.4737084633031845e-38
# test: pakts473 and PKA given PIP2 -> pval=2.087998621538299e-38
# test: pakts473 and PKA given PIP3 -> pval=1.6340689220149117e-38
# test: pakts473 and PKA given perk -> pval=2.2329639752391876e-13
# test: pakts473 and PKA given PKC -> pval=2.420078296917845e-38
# test: pakts473 and PKA given P38 -> pval=1.7506471443333363e-38
# test: pakts473 and PKA given pjnk -> pval=2.2018456911480692e-38
# test: PKA and perk given praf -> pval=7.54390685357959e-27
# test: PKA and perk given pmek -> pval=7.164954037055708e-27
# test: PKA and perk given plcg -> pval=5.826226697211581e-27
# test: PKA and perk given PIP2 -> pval=9.427969733719193e-27
# test: PKA and perk given PIP3 -> pval=6.961977661643675e-27
# test: PKA and perk given pakts473 -> pval=0.39378726952547793
# test: PKA and perk given PKC -> pval=8.57369036293957e-27
# test: PKA and perk given P38 -> pval=5.671912252992131e-27
# test: PKA and perk given pjnk -> pval=9.781040446619927e-27
# test: PKA and pakts473 given praf -> pval=1.7399024829647947e-38
# test: PKA and pakts473 given pmek -> pval=1.9204063398399243e-38
# test: PKA and pakts473 given plcg -> pval=1.4737084633031845e-38
# test: PKA and pakts473 given PIP2 -> pval=2.087998621538299e-38
# test: PKA and pakts473 given PIP3 -> pval=1.6340689220149117e-38
# test: PKA and pakts473 given perk -> pval=2.2329639752391876e-13
# test: PKA and pakts473 given PKC -> pval=2.420078296917845e-38
# test: PKA and pakts473 given P38 -> pval=1.7506471443333363e-38
# test: PKA and pakts473 given pjnk -> pval=2.2018456911480692e-38
# test: PKA and PKC given praf -> pval=0.27264052309048636
# test: PKA and PKC given pmek -> pval=0.27459387982214584
# test: PKA and PKC given plcg -> pval=0.2741933623861586
# test: PKA and PKC given PIP2 -> pval=0.2659198314151628
# test: PKA and PKC given PIP3 -> pval=0.27224293609599076
# test: PKA and PKC given perk -> pval=0.3246391041735065
# test: PKA and PKC given pakts473 -> pval=0.3955065867770112
# test: PKA and PKC given P38 -> pval=0.44286698270136426
# independence found: PKA and PKC given {P38}
# test: PKA and pjnk given praf -> pval=0.33943221603424567
# test: PKA and pjnk given pmek -> pval=0.33539199751130655
# test: PKA and pjnk given plcg -> pval=0.35082010712398115
# test: PKA and pjnk given PIP2 -> pval=0.3362716558093254
# test: PKA and pjnk given PIP3 -> pval=0.338998444673279
# test: PKA and pjnk given perk -> pval=0.5181617882881173
# independence found: PKA and pjnk given {perk}
# test: PKC and P38 given praf -> pval=2.618589698373794e-115
# test: PKC and P38 given pmek -> pval=2.1588290151151913e-115
# test: PKC and P38 given plcg -> pval=1.160328666131391e-115
# test: PKC and P38 given PIP2 -> pval=9.032513066953797e-116
# test: PKC and P38 given PIP3 -> pval=1.183074250241087e-115
# test: PKC and P38 given perk -> pval=5.890572895567145e-116
# test: PKC and P38 given pakts473 -> pval=9.048299433455144e-116
# test: PKC and P38 given PKA -> pval=1.6395523932581724e-115
# test: PKC and P38 given pjnk -> pval=7.5811338011351135e-118
# test: PKC and pjnk given praf -> pval=2.558108603217442e-15
# test: PKC and pjnk given pmek -> pval=1.3175122249405548e-15
# test: PKC and pjnk given plcg -> pval=2.3392031949957236e-15
# test: PKC and pjnk given PIP2 -> pval=2.2948166349893353e-15
# test: PKC and pjnk given PIP3 -> pval=2.0090100078213274e-15
# test: PKC and pjnk given perk -> pval=2.4767006990247617e-15
# test: PKC and pjnk given pakts473 -> pval=2.470825945575057e-15
# test: PKC and pjnk given PKA -> pval=2.8132731443906727e-15
# test: PKC and pjnk given P38 -> pval=1.3304134380434706e-17
# test: P38 and praf given pmek -> pval=0.2629169015855697
# test: P38 and praf given plcg -> pval=0.09384553974544577
# test: P38 and praf given PIP2 -> pval=0.09380422003622749
# test: P38 and praf given PIP3 -> pval=0.09289476046967415
# test: P38 and praf given perk -> pval=0.09152714601129876
# test: P38 and praf given pakts473 -> pval=0.09346560946832527
# test: P38 and praf given PKA -> pval=0.0939594561076349
# test: P38 and praf given PKC -> pval=0.26239837764141366
# test: P38 and praf given pjnk -> pval=0.10200778117681907
# test: P38 and PKC given praf -> pval=2.618589698373794e-115
# test: P38 and PKC given pmek -> pval=2.1588290151151913e-115
# test: P38 and PKC given plcg -> pval=1.160328666131391e-115
# test: P38 and PKC given PIP2 -> pval=9.032513066953797e-116
# test: P38 and PKC given PIP3 -> pval=1.183074250241087e-115
# test: P38 and PKC given perk -> pval=5.890572895567145e-116
# test: P38 and PKC given pakts473 -> pval=9.048299433455144e-116
# test: P38 and PKC given PKA -> pval=1.6395523932581724e-115
# test: P38 and PKC given pjnk -> pval=7.5811338011351135e-118
# test: P38 and pjnk given praf -> pval=0.015471953773658533
# test: P38 and pjnk given pmek -> pval=0.01219531985034964
# test: P38 and pjnk given plcg -> pval=0.014207788113187552
# test: P38 and pjnk given PIP2 -> pval=0.0142845513456677
# test: P38 and pjnk given PIP3 -> pval=0.014200486159329595
# test: P38 and pjnk given perk -> pval=0.013385531176850055
# test: P38 and pjnk given pakts473 -> pval=0.014303762831292359
# test: P38 and pjnk given PKA -> pval=0.015320512983610646
# test: P38 and pjnk given PKC -> pval=5.974222979861021e-05
# test: pjnk and pmek given praf -> pval=0.02169383910495845
# test: pjnk and pmek given plcg -> pval=0.2091225264927847
# test: pjnk and pmek given PIP2 -> pval=0.21202730912771614
# test: pjnk and pmek given PIP3 -> pval=0.1968318951491581
# test: pjnk and pmek given perk -> pval=0.22217421279884172
# test: pjnk and pmek given pakts473 -> pval=0.21233539852670025
# test: pjnk and pmek given PKA -> pval=0.21319399665221642
# test: pjnk and pmek given PKC -> pval=0.10757752389893874
# test: pjnk and pmek given P38 -> pval=0.17699477989162737
# test: pjnk and plcg given praf -> pval=0.08403978095703178
# test: pjnk and plcg given pmek -> pval=0.07998930143328802
# test: pjnk and plcg given PIP2 -> pval=0.08408776650246755
# test: pjnk and plcg given PIP3 -> pval=0.09690573141277124
# test: pjnk and plcg given perk -> pval=0.07571167455199716
# test: pjnk and plcg given pakts473 -> pval=0.07925198567886454
# test: pjnk and plcg given PKA -> pval=0.0843120687342489
# test: pjnk and plcg given PKC -> pval=0.08607478701167394
# test: pjnk and plcg given P38 -> pval=0.08122603934659407
# test: pjnk and PKC given praf -> pval=2.558108603217442e-15
# test: pjnk and PKC given pmek -> pval=1.3175122249405548e-15
# test: pjnk and PKC given plcg -> pval=2.3392031949957236e-15
# test: pjnk and PKC given PIP2 -> pval=2.2948166349893353e-15
# test: pjnk and PKC given PIP3 -> pval=2.0090100078213274e-15
# test: pjnk and PKC given perk -> pval=2.4767006990247617e-15
# test: pjnk and PKC given pakts473 -> pval=2.470825945575057e-15
# test: pjnk and PKC given PKA -> pval=2.8132731443906727e-15
# test: pjnk and PKC given P38 -> pval=1.3304134380434706e-17
# test: pjnk and P38 given praf -> pval=0.015471953773658533
# test: pjnk and P38 given pmek -> pval=0.01219531985034964
# test: pjnk and P38 given plcg -> pval=0.014207788113187552
# test: pjnk and P38 given PIP2 -> pval=0.0142845513456677
# test: pjnk and P38 given PIP3 -> pval=0.014200486159329595
# test: pjnk and P38 given perk -> pval=0.013385531176850055
# test: pjnk and P38 given pakts473 -> pval=0.014303762831292359
# test: pjnk and P38 given PKA -> pval=0.015320512983610646
# test: pjnk and P38 given PKC -> pval=5.974222979861021e-05
# test: praf and pmek given plcg, PIP2 -> pval=6.632766621550825e-129
# test: praf and pmek given plcg, PIP3 -> pval=1.44622847377496e-128
# test: praf and pmek given plcg, perk -> pval=6.234721562378759e-129
# test: praf and pmek given plcg, pakts473 -> pval=1.218913722796452e-128
# test: praf and pmek given plcg, PKA -> pval=1.236146181691548e-128
# test: praf and pmek given plcg, PKC -> pval=2.2504997345935595e-128
# test: praf and pmek given plcg, P38 -> pval=2.7017547646423546e-128
# test: praf and pmek given plcg, pjnk -> pval=2.011522350874285e-129
# test: praf and pmek given PIP2, PIP3 -> pval=1.1757500948816265e-128
# test: praf and pmek given PIP2, perk -> pval=3.811489396659149e-129
# test: praf and pmek given PIP2, pakts473 -> pval=7.093071009231657e-129
# test: praf and pmek given PIP2, PKA -> pval=7.051963538012127e-129
# test: praf and pmek given PIP2, PKC -> pval=1.2752411318636423e-128
# test: praf and pmek given PIP2, P38 -> pval=1.5593350687316534e-128
# test: praf and pmek given PIP2, pjnk -> pval=1.0719311056491254e-129
# test: praf and pmek given PIP3, perk -> pval=8.031483222760094e-129
# test: praf and pmek given PIP3, pakts473 -> pval=1.523695211964875e-128
# test: praf and pmek given PIP3, PKA -> pval=1.6448941871247173e-128
# test: praf and pmek given PIP3, PKC -> pval=3.0789197177008995e-128
# test: praf and pmek given PIP3, P38 -> pval=3.6375280926353394e-128
# test: praf and pmek given PIP3, pjnk -> pval=2.4273386618035e-129
# test: praf and pmek given perk, pakts473 -> pval=1.208119376939903e-128
# test: praf and pmek given perk, PKA -> pval=5.4528276337968434e-129
# test: praf and pmek given perk, PKC -> pval=1.1656971487813864e-128
# test: praf and pmek given perk, P38 -> pval=1.371709589653156e-128
# test: praf and pmek given perk, pjnk -> pval=1.0559786055192567e-129
# test: praf and pmek given pakts473, PKA -> pval=1.1342472624875043e-128
# test: praf and pmek given pakts473, PKC -> pval=2.197080167701123e-128
# test: praf and pmek given pakts473, P38 -> pval=2.671172793020318e-128
# test: praf and pmek given pakts473, pjnk -> pval=1.9467242655241055e-129
# test: praf and pmek given PKA, PKC -> pval=2.2573534769457624e-128
# test: praf and pmek given PKA, P38 -> pval=2.697085419870417e-128
# test: praf and pmek given PKA, pjnk -> pval=1.9041875076339264e-129
# test: praf and pmek given PKC, P38 -> pval=2.7054968097813103e-128
# test: praf and pmek given PKC, pjnk -> pval=3.7297540723018056e-129
# test: praf and pmek given P38, pjnk -> pval=4.665275452526177e-129
# test: praf and pakts473 given pmek, plcg -> pval=0.30487068832811837
# test: praf and pakts473 given pmek, PIP2 -> pval=0.3212450085173759
# test: praf and pakts473 given pmek, PIP3 -> pval=0.3012917604681127
# test: praf and pakts473 given pmek, perk -> pval=0.8592927717722215
# independence found: praf and pakts473 given {pmek, perk}
# test: praf and P38 given pmek, plcg -> pval=0.26312463633835087
# test: praf and P38 given pmek, PIP2 -> pval=0.2667885119421317
# test: praf and P38 given pmek, PIP3 -> pval=0.2649306352283702
# test: praf and P38 given pmek, perk -> pval=0.25095064124343724
# test: praf and P38 given pmek, pakts473 -> pval=0.2622140113344464
# test: praf and P38 given pmek, PKA -> pval=0.26195324932050856
# test: praf and P38 given pmek, PKC -> pval=0.3409988132590709
# test: praf and P38 given pmek, pjnk -> pval=0.3409444218199955
# test: praf and P38 given plcg, PIP2 -> pval=0.0940549698216492
# test: praf and P38 given plcg, PIP3 -> pval=0.0931416514074284
# test: praf and P38 given plcg, perk -> pval=0.09160225537763712
# test: praf and P38 given plcg, pakts473 -> pval=0.09363786258098251
# test: praf and P38 given plcg, PKA -> pval=0.0940934165291973
# test: praf and P38 given plcg, PKC -> pval=0.2601631603825254
# test: praf and P38 given plcg, pjnk -> pval=0.10158216448330605
# test: praf and P38 given PIP2, PIP3 -> pval=0.09346631044809982
# test: praf and P38 given PIP2, perk -> pval=0.09162703740578178
# test: praf and P38 given PIP2, pakts473 -> pval=0.0935821053424378
# test: praf and P38 given PIP2, PKA -> pval=0.09410309737399501
# test: praf and P38 given PIP2, PKC -> pval=0.2623880505392103
# test: praf and P38 given PIP2, pjnk -> pval=0.10215162837651451
# test: praf and P38 given PIP3, perk -> pval=0.09095056588825018
# test: praf and P38 given PIP3, pakts473 -> pval=0.09274859329072496
# test: praf and P38 given PIP3, PKA -> pval=0.09318660280894642
# test: praf and P38 given PIP3, PKC -> pval=0.26561018717111107
# test: praf and P38 given PIP3, pjnk -> pval=0.10078731855157938
# test: praf and P38 given perk, pakts473 -> pval=0.09999474267641693
# test: praf and P38 given perk, PKA -> pval=0.09045024641635767
# test: praf and P38 given perk, PKC -> pval=0.2527654254415781
# test: praf and P38 given perk, pjnk -> pval=0.09949483257284156
# test: praf and P38 given pakts473, PKA -> pval=0.09101958758031921
# test: praf and P38 given pakts473, PKC -> pval=0.2518133179789097
# test: praf and P38 given pakts473, pjnk -> pval=0.10145756112231362
# test: praf and P38 given PKA, PKC -> pval=0.26267354086957156
# test: praf and P38 given PKA, pjnk -> pval=0.10222839659520866
# test: praf and P38 given PKC, pjnk -> pval=0.24535915373107794
# test: pmek and praf given plcg, PIP2 -> pval=6.632766621550825e-129
# test: pmek and praf given plcg, PIP3 -> pval=1.44622847377496e-128
# test: pmek and praf given plcg, perk -> pval=6.234721562378759e-129
# test: pmek and praf given plcg, pakts473 -> pval=1.218913722796452e-128
# test: pmek and praf given plcg, PKA -> pval=1.236146181691548e-128
# test: pmek and praf given plcg, PKC -> pval=2.2504997345935595e-128
# test: pmek and praf given plcg, P38 -> pval=2.7017547646423546e-128
# test: pmek and praf given plcg, pjnk -> pval=2.011522350874285e-129
# test: pmek and praf given PIP2, PIP3 -> pval=1.1757500948816265e-128
# test: pmek and praf given PIP2, perk -> pval=3.811489396659149e-129
# test: pmek and praf given PIP2, pakts473 -> pval=7.093071009231657e-129
# test: pmek and praf given PIP2, PKA -> pval=7.051963538012127e-129
# test: pmek and praf given PIP2, PKC -> pval=1.2752411318636423e-128
# test: pmek and praf given PIP2, P38 -> pval=1.5593350687316534e-128
# test: pmek and praf given PIP2, pjnk -> pval=1.0719311056491254e-129
# test: pmek and praf given PIP3, perk -> pval=8.031483222760094e-129
# test: pmek and praf given PIP3, pakts473 -> pval=1.523695211964875e-128
# test: pmek and praf given PIP3, PKA -> pval=1.6448941871247173e-128
# test: pmek and praf given PIP3, PKC -> pval=3.0789197177008995e-128
# test: pmek and praf given PIP3, P38 -> pval=3.6375280926353394e-128
# test: pmek and praf given PIP3, pjnk -> pval=2.4273386618035e-129
# test: pmek and praf given perk, pakts473 -> pval=1.208119376939903e-128
# test: pmek and praf given perk, PKA -> pval=5.4528276337968434e-129
# test: pmek and praf given perk, PKC -> pval=1.1656971487813864e-128
# test: pmek and praf given perk, P38 -> pval=1.371709589653156e-128
# test: pmek and praf given perk, pjnk -> pval=1.0559786055192567e-129
# test: pmek and praf given pakts473, PKA -> pval=1.1342472624875043e-128
# test: pmek and praf given pakts473, PKC -> pval=2.197080167701123e-128
# test: pmek and praf given pakts473, P38 -> pval=2.671172793020318e-128
# test: pmek and praf given pakts473, pjnk -> pval=1.9467242655241055e-129
# test: pmek and praf given PKA, PKC -> pval=2.2573534769457624e-128
# test: pmek and praf given PKA, P38 -> pval=2.697085419870417e-128
# test: pmek and praf given PKA, pjnk -> pval=1.9041875076339264e-129
# test: pmek and praf given PKC, P38 -> pval=2.7054968097813103e-128
# test: pmek and praf given PKC, pjnk -> pval=3.7297540723018056e-129
# test: pmek and praf given P38, pjnk -> pval=4.665275452526177e-129
# test: pmek and PIP3 given praf, plcg -> pval=0.05893710159791701
# test: pmek and PIP3 given praf, PIP2 -> pval=0.17645935515445135
# test: pmek and PIP3 given praf, perk -> pval=0.05894114757767718
# test: pmek and PIP3 given praf, pakts473 -> pval=0.06352729405348766
# test: pmek and PIP3 given praf, PKA -> pval=0.06622338078269427
# test: pmek and PIP3 given praf, PKC -> pval=0.0652636587927823
# test: pmek and PIP3 given praf, P38 -> pval=0.06613270672261692
# test: pmek and PIP3 given praf, pjnk -> pval=0.05773972916669627
# test: pmek and PIP3 given plcg, PIP2 -> pval=0.09351420938665583
# test: pmek and PIP3 given plcg, perk -> pval=0.04615891590275797
# test: pmek and PIP3 given plcg, pakts473 -> pval=0.05093478116293669
# test: pmek and PIP3 given plcg, PKA -> pval=0.049092756929974994
# test: pmek and PIP3 given plcg, PKC -> pval=0.04682751141958484
# test: pmek and PIP3 given plcg, P38 -> pval=0.048309298940437534
# test: pmek and PIP3 given plcg, pjnk -> pval=0.04653979109682569
# test: pmek and PIP3 given PIP2, perk -> pval=0.08599456589284787
# test: pmek and PIP3 given PIP2, pakts473 -> pval=0.09581389389084664
# test: pmek and PIP3 given PIP2, PKA -> pval=0.09259124817537055
# test: pmek and PIP3 given PIP2, PKC -> pval=0.08686014505365479
# test: pmek and PIP3 given PIP2, P38 -> pval=0.09154278729310114
# test: pmek and PIP3 given PIP2, pjnk -> pval=0.08636461045051223
# test: pmek and PIP3 given perk, pakts473 -> pval=0.04717881779690911
# test: pmek and PIP3 given perk, PKA -> pval=0.044225086394021416
# test: pmek and PIP3 given perk, PKC -> pval=0.042805412921179446
# test: pmek and PIP3 given perk, P38 -> pval=0.04422643469455473
# test: pmek and PIP3 given perk, pjnk -> pval=0.04169663442213474
# test: pmek and PIP3 given pakts473, PKA -> pval=0.0489885632107332
# test: pmek and PIP3 given pakts473, PKC -> pval=0.04678392621246663
# test: pmek and PIP3 given pakts473, P38 -> pval=0.048202573698243927
# test: pmek and PIP3 given pakts473, pjnk -> pval=0.04546099324749819
# test: pmek and PIP3 given PKA, PKC -> pval=0.04538893317924568
# test: pmek and PIP3 given PKA, P38 -> pval=0.04663871115999667
# test: pmek and PIP3 given PKA, pjnk -> pval=0.04387501367996404
# test: pmek and PIP3 given PKC, P38 -> pval=0.045849662913604955
# test: pmek and PIP3 given PKC, pjnk -> pval=0.040155210629142256
# test: pmek and PIP3 given P38, pjnk -> pval=0.04278538793524662
# test: pmek and pjnk given praf, plcg -> pval=0.02245704732015362
# test: pmek and pjnk given praf, PIP2 -> pval=0.02096580213068531
# test: pmek and pjnk given praf, PIP3 -> pval=0.019114590209614347
# test: pmek and pjnk given praf, perk -> pval=0.02417760827473737
# test: pmek and pjnk given praf, pakts473 -> pval=0.02221430658388109
# test: pmek and pjnk given praf, PKA -> pval=0.021370776277337807
# test: pmek and pjnk given praf, PKC -> pval=0.012814626357056805
# test: pmek and pjnk given praf, P38 -> pval=0.020855466887189436
# test: pmek and pjnk given plcg, PIP2 -> pval=0.2082099846855694
# test: pmek and pjnk given plcg, PIP3 -> pval=0.19671367449123697
# test: pmek and pjnk given plcg, perk -> pval=0.21643525971794358
# test: pmek and pjnk given plcg, pakts473 -> pval=0.20618184768201875
# test: pmek and pjnk given plcg, PKA -> pval=0.20741400457215298
# test: pmek and pjnk given plcg, PKC -> pval=0.10420839042116388
# test: pmek and pjnk given plcg, P38 -> pval=0.17182186095393412
# test: pmek and pjnk given PIP2, PIP3 -> pval=0.19737233507552807
# test: pmek and pjnk given PIP2, perk -> pval=0.21861312953358758
# test: pmek and pjnk given PIP2, pakts473 -> pval=0.2092042814817201
# test: pmek and pjnk given PIP2, PKA -> pval=0.20984204832491166
# test: pmek and pjnk given PIP2, PKC -> pval=0.10702385463267212
# test: pmek and pjnk given PIP2, P38 -> pval=0.17413443309438395
# test: pmek and pjnk given PIP3, perk -> pval=0.2042446793766263
# test: pmek and pjnk given PIP3, pakts473 -> pval=0.19496499771625436
# test: pmek and pjnk given PIP3, PKA -> pval=0.19510311009399697
# test: pmek and pjnk given PIP3, PKC -> pval=0.09465411186612101
# test: pmek and pjnk given PIP3, P38 -> pval=0.16087226921399225
# test: pmek and pjnk given perk, pakts473 -> pval=0.23540961051481885
# test: pmek and pjnk given perk, PKA -> pval=0.2191135945857965
# test: pmek and pjnk given perk, PKC -> pval=0.11153059487447303
# test: pmek and pjnk given perk, P38 -> pval=0.1832102547898609
# test: pmek and pjnk given pakts473, PKA -> pval=0.21256909546926758
# test: pmek and pjnk given pakts473, PKC -> pval=0.10669744109283931
# test: pmek and pjnk given pakts473, P38 -> pval=0.17463433557938982
# test: pmek and pjnk given PKA, PKC -> pval=0.10711657918107313
# test: pmek and pjnk given PKA, P38 -> pval=0.1758660248043024
# test: pmek and pjnk given PKC, P38 -> pval=0.12441132133775258
# test: plcg and PIP2 given praf, pmek -> pval=0.014169547565408886
# test: plcg and PIP2 given praf, PIP3 -> pval=0.2899713947370886
# test: plcg and PIP2 given praf, perk -> pval=0.016502478058298076
# test: plcg and PIP2 given praf, pakts473 -> pval=0.01537071937629794
# test: plcg and PIP2 given praf, PKA -> pval=0.014410715489343102
# test: plcg and PIP2 given praf, PKC -> pval=0.015089872358413437
# test: plcg and PIP2 given praf, P38 -> pval=0.014888477552428052
# test: plcg and PIP2 given praf, pjnk -> pval=0.015214761402830004
# test: plcg and PIP2 given pmek, PIP3 -> pval=0.2927218962506904
# test: plcg and PIP2 given pmek, perk -> pval=0.01678062488685028
# test: plcg and PIP2 given pmek, pakts473 -> pval=0.015690139280919325
# test: plcg and PIP2 given pmek, PKA -> pval=0.014704514703934551
# test: plcg and PIP2 given pmek, PKC -> pval=0.015396041346225464
# test: plcg and PIP2 given pmek, P38 -> pval=0.015185661898932529
# test: plcg and PIP2 given pmek, pjnk -> pval=0.015653649013491856
# test: plcg and PIP2 given PIP3, perk -> pval=0.3245222036161163
# test: plcg and PIP2 given PIP3, pakts473 -> pval=0.3072194421935569
# test: plcg and PIP2 given PIP3, PKA -> pval=0.28735565707244126
# test: plcg and PIP2 given PIP3, PKC -> pval=0.29723907854806214
# test: plcg and PIP2 given PIP3, P38 -> pval=0.29278382327581376
# test: plcg and PIP2 given PIP3, pjnk -> pval=0.29031943629114304
# test: plcg and PIP2 given perk, pakts473 -> pval=0.016819308337129715
# test: plcg and PIP2 given perk, PKA -> pval=0.015950327274998777
# test: plcg and PIP2 given perk, PKC -> pval=0.016746205764203888
# test: plcg and PIP2 given perk, P38 -> pval=0.01647581152421976
# test: plcg and PIP2 given perk, pjnk -> pval=0.016954124844742936
# test: plcg and PIP2 given pakts473, PKA -> pval=0.014576037947922808
# test: plcg and PIP2 given pakts473, PKC -> pval=0.015602127986704104
# test: plcg and PIP2 given pakts473, P38 -> pval=0.015342540511417868
# test: plcg and PIP2 given pakts473, pjnk -> pval=0.01571680774013437
# test: plcg and PIP2 given PKA, PKC -> pval=0.014620395868517617
# test: plcg and PIP2 given PKA, P38 -> pval=0.014400098651085406
# test: plcg and PIP2 given PKA, pjnk -> pval=0.014783240856147352
# test: plcg and PIP2 given PKC, P38 -> pval=0.015369992930027724
# test: plcg and PIP2 given PKC, pjnk -> pval=0.015079006462668581
# test: plcg and PIP2 given P38, pjnk -> pval=0.015247982566909244
# test: plcg and PIP3 given praf, pmek -> pval=0.00010739130202985256
# test: plcg and PIP3 given praf, PIP2 -> pval=0.0015663505512829579
# test: plcg and PIP3 given praf, perk -> pval=9.882212998471322e-05
# test: plcg and PIP3 given praf, pakts473 -> pval=0.00010260658613426717
# test: plcg and PIP3 given praf, PKA -> pval=0.00011876788901072045
# test: plcg and PIP3 given praf, PKC -> pval=0.00011638918643506892
# test: plcg and PIP3 given praf, P38 -> pval=0.00011898261530925203
# test: plcg and PIP3 given praf, pjnk -> pval=0.00013632385860252075
# test: plcg and PIP3 given pmek, PIP2 -> pval=0.0014836911622496372
# test: plcg and PIP3 given pmek, perk -> pval=9.41773206607921e-05
# test: plcg and PIP3 given pmek, pakts473 -> pval=9.869586218354593e-05
# test: plcg and PIP3 given pmek, PKA -> pval=0.00011397256272799047
# test: plcg and PIP3 given pmek, PKC -> pval=0.00011138503082068851
# test: plcg and PIP3 given pmek, P38 -> pval=0.00011415464465755452
# test: plcg and PIP3 given pmek, pjnk -> pval=0.00013435222404391503
# test: plcg and PIP3 given PIP2, perk -> pval=0.001182364144054341
# test: plcg and PIP3 given PIP2, pakts473 -> pval=0.0012648903246860123
# test: plcg and PIP3 given PIP2, PKA -> pval=0.001489082548927897
# test: plcg and PIP3 given PIP2, PKC -> pval=0.0014289520396061602
# test: plcg and PIP3 given PIP2, P38 -> pval=0.001465769204244831
# test: plcg and PIP3 given PIP2, pjnk -> pval=0.0016487368251898984
# test: plcg and PIP3 given perk, pakts473 -> pval=9.296414922946573e-05
# test: plcg and PIP3 given perk, PKA -> pval=8.649343925157138e-05
# test: plcg and PIP3 given perk, PKC -> pval=8.960714834075091e-05
# test: plcg and PIP3 given perk, P38 -> pval=9.179597779006212e-05
# test: plcg and PIP3 given perk, pjnk -> pval=0.00010520356641482404
# test: plcg and PIP3 given pakts473, PKA -> pval=8.857434829240839e-05
# test: plcg and PIP3 given pakts473, PKC -> pval=9.301066407895154e-05
# test: plcg and PIP3 given pakts473, P38 -> pval=9.532356910421664e-05
# test: plcg and PIP3 given pakts473, pjnk -> pval=0.00010950065816640097
# test: plcg and PIP3 given PKA, PKC -> pval=0.0001082563400265008
# test: plcg and PIP3 given PKA, P38 -> pval=0.00011048231806514364
# test: plcg and PIP3 given PKA, pjnk -> pval=0.0001272106895631516
# test: plcg and PIP3 given PKC, P38 -> pval=0.00010725620446977646
# test: plcg and PIP3 given PKC, pjnk -> pval=0.00012875049955702448
# test: plcg and PIP3 given P38, pjnk -> pval=0.000127871261732615
# test: plcg and pjnk given praf, pmek -> pval=0.08708071451958489
# test: plcg and pjnk given praf, PIP2 -> pval=0.08625766697266643
# test: plcg and pjnk given praf, PIP3 -> pval=0.0988142694391676
# test: plcg and pjnk given praf, perk -> pval=0.0777059397545747
# test: plcg and pjnk given praf, pakts473 -> pval=0.08133752220464506
# test: plcg and pjnk given praf, PKA -> pval=0.08648403920615291
# test: plcg and pjnk given praf, PKC -> pval=0.08703411765277892
# test: plcg and pjnk given praf, P38 -> pval=0.08284345948418247
# test: plcg and pjnk given pmek, PIP2 -> pval=0.08281936138057817
# test: plcg and pjnk given pmek, PIP3 -> pval=0.0969301640305726
# test: plcg and pjnk given pmek, perk -> pval=0.07407853211219026
# test: plcg and pjnk given pmek, pakts473 -> pval=0.07729008215099908
# test: plcg and pjnk given pmek, PKA -> pval=0.08235244956491579
# test: plcg and pjnk given pmek, PKC -> pval=0.08345250037677135
# test: plcg and pjnk given pmek, P38 -> pval=0.0791114875984024
# test: plcg and pjnk given PIP2, PIP3 -> pval=0.09639021351306103
# test: plcg and pjnk given PIP2, perk -> pval=0.07825994180070982
# test: plcg and pjnk given PIP2, pakts473 -> pval=0.08149240254824529
# test: plcg and pjnk given PIP2, PKA -> pval=0.08693222937990254
# test: plcg and pjnk given PIP2, PKC -> pval=0.08611231991725594
# test: plcg and pjnk given PIP2, P38 -> pval=0.08364959157537731
# test: plcg and pjnk given PIP3, perk -> pval=0.08894129630992581
# test: plcg and pjnk given PIP3, pakts473 -> pval=0.09335689611919419
# test: plcg and pjnk given PIP3, PKA -> pval=0.09967586702457544
# test: plcg and pjnk given PIP3, PKC -> pval=0.1057342711114322
# test: plcg and pjnk given PIP3, P38 -> pval=0.09643954500944575
# test: plcg and pjnk given perk, pakts473 -> pval=0.07498058963389416
# test: plcg and pjnk given perk, PKA -> pval=0.0788099936687241
# test: plcg and pjnk given perk, PKC -> pval=0.08024614774480218
# test: plcg and pjnk given perk, P38 -> pval=0.07470216846318804
# test: plcg and pjnk given pakts473, PKA -> pval=0.08307063035516608
# test: plcg and pjnk given pakts473, PKC -> pval=0.08424264834137728
# test: plcg and pjnk given pakts473, P38 -> pval=0.07856527846161987
# test: plcg and pjnk given PKA, PKC -> pval=0.08789609430860874
# test: plcg and pjnk given PKA, P38 -> pval=0.08347088134637065
# test: plcg and pjnk given PKC, P38 -> pval=0.09022878749448651
# test: PIP2 and plcg given praf, pmek -> pval=0.014169547565408886
# test: PIP2 and plcg given praf, PIP3 -> pval=0.2899713947370886
# test: PIP2 and plcg given praf, perk -> pval=0.016502478058298076
# test: PIP2 and plcg given praf, pakts473 -> pval=0.01537071937629794
# test: PIP2 and plcg given praf, PKA -> pval=0.014410715489343102
# test: PIP2 and plcg given praf, PKC -> pval=0.015089872358413437
# test: PIP2 and plcg given praf, P38 -> pval=0.014888477552428052
# test: PIP2 and plcg given praf, pjnk -> pval=0.015214761402830004
# test: PIP2 and plcg given pmek, PIP3 -> pval=0.2927218962506904
# test: PIP2 and plcg given pmek, perk -> pval=0.01678062488685028
# test: PIP2 and plcg given pmek, pakts473 -> pval=0.015690139280919325
# test: PIP2 and plcg given pmek, PKA -> pval=0.014704514703934551
# test: PIP2 and plcg given pmek, PKC -> pval=0.015396041346225464
# test: PIP2 and plcg given pmek, P38 -> pval=0.015185661898932529
# test: PIP2 and plcg given pmek, pjnk -> pval=0.015653649013491856
# test: PIP2 and plcg given PIP3, perk -> pval=0.3245222036161163
# test: PIP2 and plcg given PIP3, pakts473 -> pval=0.3072194421935569
# test: PIP2 and plcg given PIP3, PKA -> pval=0.28735565707244126
# test: PIP2 and plcg given PIP3, PKC -> pval=0.29723907854806214
# test: PIP2 and plcg given PIP3, P38 -> pval=0.29278382327581376
# test: PIP2 and plcg given PIP3, pjnk -> pval=0.29031943629114304
# test: PIP2 and plcg given perk, pakts473 -> pval=0.016819308337129715
# test: PIP2 and plcg given perk, PKA -> pval=0.015950327274998777
# test: PIP2 and plcg given perk, PKC -> pval=0.016746205764203888
# test: PIP2 and plcg given perk, P38 -> pval=0.01647581152421976
# test: PIP2 and plcg given perk, pjnk -> pval=0.016954124844742936
# test: PIP2 and plcg given pakts473, PKA -> pval=0.014576037947922808
# test: PIP2 and plcg given pakts473, PKC -> pval=0.015602127986704104
# test: PIP2 and plcg given pakts473, P38 -> pval=0.015342540511417868
# test: PIP2 and plcg given pakts473, pjnk -> pval=0.01571680774013437
# test: PIP2 and plcg given PKA, PKC -> pval=0.014620395868517617
# test: PIP2 and plcg given PKA, P38 -> pval=0.014400098651085406
# test: PIP2 and plcg given PKA, pjnk -> pval=0.014783240856147352
# test: PIP2 and plcg given PKC, P38 -> pval=0.015369992930027724
# test: PIP2 and plcg given PKC, pjnk -> pval=0.015079006462668581
# ...
# test: pjnk and plcg given pmek, PIP2, PKA -> pval=0.08564508500981662
# test: pjnk and plcg given pmek, PIP2, PKC -> pval=0.08439220414217077
# test: pjnk and plcg given pmek, PIP2, P38 -> pval=0.08224183126244737
# test: pjnk and plcg given pmek, PIP3, perk -> pval=0.0891857185719328
# test: pjnk and plcg given pmek, PIP3, pakts473 -> pval=0.09328943697950655
# test: pjnk and plcg given pmek, PIP3, PKA -> pval=0.09971998604562039
# test: pjnk and plcg given pmek, PIP3, PKC -> pval=0.10577133982317044
# test: pjnk and plcg given pmek, PIP3, P38 -> pval=0.09643089848766921
# test: pjnk and plcg given pmek, perk, pakts473 -> pval=0.07351730492922597
# test: pjnk and plcg given pmek, perk, PKA -> pval=0.07718683334131395
# test: pjnk and plcg given pmek, perk, PKC -> pval=0.07799125376780527
# test: pjnk and plcg given pmek, perk, P38 -> pval=0.07289841276427325
# test: pjnk and plcg given pmek, pakts473, PKA -> pval=0.08103116984005886
# test: pjnk and plcg given pmek, pakts473, PKC -> pval=0.08155928400682799
# test: pjnk and plcg given pmek, pakts473, P38 -> pval=0.07640898962544677
# test: pjnk and plcg given pmek, PKA, PKC -> pval=0.08524120018060836
# test: pjnk and plcg given pmek, PKA, P38 -> pval=0.08131682344996402
# test: pjnk and plcg given pmek, PKC, P38 -> pval=0.08759962320263028
# test: pjnk and plcg given PIP2, PIP3, perk -> pval=0.08886886015318278
# test: pjnk and plcg given PIP2, PIP3, pakts473 -> pval=0.09300967620376517
# test: pjnk and plcg given PIP2, PIP3, PKA -> pval=0.0993379007769846
# test: pjnk and plcg given PIP2, PIP3, PKC -> pval=0.10352170526041575
# test: pjnk and plcg given PIP2, PIP3, P38 -> pval=0.09602792127209625
# test: pjnk and plcg given PIP2, perk, pakts473 -> pval=0.07779579997292309
# test: pjnk and plcg given PIP2, perk, PKA -> pval=0.08157626212434721
# test: pjnk and plcg given PIP2, perk, PKC -> pval=0.08078170899778492
# test: pjnk and plcg given PIP2, perk, P38 -> pval=0.07749801241771515
# test: pjnk and plcg given PIP2, pakts473, PKA -> pval=0.08566792113802583
# test: pjnk and plcg given PIP2, pakts473, PKC -> pval=0.08437427647936942
# test: pjnk and plcg given PIP2, pakts473, P38 -> pval=0.08104437012562266
# test: pjnk and plcg given PIP2, PKA, PKC -> pval=0.08821800648875962
# test: pjnk and plcg given PIP2, PKA, P38 -> pval=0.08631120410916768
# test: pjnk and plcg given PIP2, PKC, P38 -> pval=0.08858490521421733
# test: pjnk and plcg given PIP3, perk, pakts473 -> pval=0.08829218861278218
# test: pjnk and plcg given PIP3, perk, PKA -> pval=0.09278180894618727
# test: pjnk and plcg given PIP3, perk, PKC -> pval=0.09808037599233418
# test: pjnk and plcg given PIP3, perk, P38 -> pval=0.0880331945821218
# test: pjnk and plcg given PIP3, pakts473, PKA -> pval=0.09820667638791894
# test: pjnk and plcg given PIP3, pakts473, PKC -> pval=0.10329469472845272
# test: pjnk and plcg given PIP3, pakts473, P38 -> pval=0.0928800503672394
# test: pjnk and plcg given PIP3, PKA, PKC -> pval=0.10788010875897128
# test: pjnk and plcg given PIP3, PKA, P38 -> pval=0.09903281827565792
# test: pjnk and plcg given PIP3, PKC, P38 -> pval=0.11182104807199486
# test: pjnk and plcg given perk, pakts473, PKA -> pval=0.07867114351185861
# test: pjnk and plcg given perk, pakts473, PKC -> pval=0.07914577397251231
# test: pjnk and plcg given perk, pakts473, P38 -> pval=0.07381931673132067
# test: pjnk and plcg given perk, PKA, PKC -> pval=0.0822500798972999
# test: pjnk and plcg given perk, PKA, P38 -> pval=0.07734879831562218
# test: pjnk and plcg given perk, PKC, P38 -> pval=0.08532986218918633
# test: pjnk and plcg given pakts473, PKA, PKC -> pval=0.08719726187052083
# test: pjnk and plcg given pakts473, PKA, P38 -> pval=0.08201992889451723
# test: pjnk and plcg given pakts473, PKC, P38 -> pval=0.0888339748800707
# test: pjnk and plcg given PKA, PKC, P38 -> pval=0.09215642302695892
# test: pjnk and PKC given praf, pmek, plcg -> pval=1.7699902815638867e-15
# test: pjnk and PKC given praf, pmek, PIP2 -> pval=1.7824966745159422e-15
# test: pjnk and PKC given praf, pmek, PIP3 -> pval=1.469880240066976e-15
# test: pjnk and PKC given praf, pmek, perk -> pval=1.877518921923862e-15
# test: pjnk and PKC given praf, pmek, pakts473 -> pval=1.865155895536319e-15
# test: pjnk and PKC given praf, pmek, PKA -> pval=2.15846705752291e-15
# test: pjnk and PKC given praf, pmek, P38 -> pval=8.28376153024875e-18
# test: pjnk and PKC given praf, plcg, PIP2 -> pval=2.828262083946357e-15
# test: pjnk and PKC given praf, plcg, PIP3 -> pval=2.5962872617825357e-15
# test: pjnk and PKC given praf, plcg, perk -> pval=3.1196985819107174e-15
# test: pjnk and PKC given praf, plcg, pakts473 -> pval=3.113864251049423e-15
# test: pjnk and PKC given praf, plcg, PKA -> pval=3.514792102605228e-15
# test: pjnk and PKC given praf, plcg, P38 -> pval=1.5963441977560226e-17
# test: pjnk and PKC given praf, PIP2, PIP3 -> pval=2.3545536569436997e-15
# test: pjnk and PKC given praf, PIP2, perk -> pval=3.094714849290611e-15
# test: pjnk and PKC given praf, PIP2, pakts473 -> pval=3.067781694224717e-15
# test: pjnk and PKC given praf, PIP2, PKA -> pval=3.526210132765695e-15
# test: pjnk and PKC given praf, PIP2, P38 -> pval=1.5058278654800377e-17
# test: pjnk and PKC given praf, PIP3, perk -> pval=2.6842350181476395e-15
# test: pjnk and PKC given praf, PIP3, pakts473 -> pval=2.6585180317560797e-15
# test: pjnk and PKC given praf, PIP3, PKA -> pval=3.0567919805123152e-15
# test: pjnk and PKC given praf, PIP3, P38 -> pval=1.2820681458467714e-17
# test: pjnk and PKC given praf, perk, pakts473 -> pval=2.612680679996972e-15
# test: pjnk and PKC given praf, perk, PKA -> pval=3.443639689622507e-15
# test: pjnk and PKC given praf, perk, P38 -> pval=1.9842665529282376e-17
# test: pjnk and PKC given praf, pakts473, PKA -> pval=3.4775966617267642e-15
# test: pjnk and PKC given praf, pakts473, P38 -> pval=1.6660314917874204e-17
# test: pjnk and PKC given praf, PKA, P38 -> pval=1.7138010551476817e-17
# test: pjnk and PKC given pmek, plcg, PIP2 -> pval=1.4785055256781581e-15
# test: pjnk and PKC given pmek, plcg, PIP3 -> pval=1.30887601454965e-15
# test: pjnk and PKC given pmek, plcg, perk -> pval=1.6375133957137405e-15
# test: pjnk and PKC given pmek, plcg, pakts473 -> pval=1.6324383707779903e-15
# test: pjnk and PKC given pmek, plcg, PKA -> pval=1.8289770770141928e-15
# test: pjnk and PKC given pmek, plcg, P38 -> pval=1.1982572439391122e-17
# test: pjnk and PKC given pmek, PIP2, PIP3 -> pval=1.1808780271837645e-15
# test: pjnk and PKC given pmek, PIP2, perk -> pval=1.6215144699010977e-15
# test: pjnk and PKC given pmek, PIP2, pakts473 -> pval=1.6072832437718417e-15
# test: pjnk and PKC given pmek, PIP2, PKA -> pval=1.8346078263568045e-15
# test: pjnk and PKC given pmek, PIP2, P38 -> pval=1.1478377998406466e-17
# test: pjnk and PKC given pmek, PIP3, perk -> pval=1.3540710353972632e-15
# test: pjnk and PKC given pmek, PIP3, pakts473 -> pval=1.339834523911652e-15
# test: pjnk and PKC given pmek, PIP3, PKA -> pval=1.530958419448379e-15
# test: pjnk and PKC given pmek, PIP3, P38 -> pval=9.33126647897771e-18
# test: pjnk and PKC given pmek, perk, pakts473 -> pval=1.3961300138837258e-15
# test: pjnk and PKC given pmek, perk, PKA -> pval=1.7979235780773002e-15
# test: pjnk and PKC given pmek, perk, P38 -> pval=1.487631329309565e-17
# test: pjnk and PKC given pmek, pakts473, PKA -> pval=1.805586675481638e-15
# test: pjnk and PKC given pmek, pakts473, P38 -> pval=1.2637142443163316e-17
# test: pjnk and PKC given pmek, PKA, P38 -> pval=1.2889217977321131e-17
# test: pjnk and PKC given plcg, PIP2, PIP3 -> pval=2.2046531080910508e-15
# test: pjnk and PKC given plcg, PIP2, perk -> pval=2.80660520414301e-15
# test: pjnk and PKC given plcg, PIP2, pakts473 -> pval=2.794194981419934e-15
# test: pjnk and PKC given plcg, PIP2, PKA -> pval=3.1366324901925343e-15
# test: pjnk and PKC given plcg, PIP2, P38 -> pval=1.5560020223326448e-17
# test: pjnk and PKC given plcg, PIP3, perk -> pval=2.5833664345773467e-15
# test: pjnk and PKC given plcg, PIP3, pakts473 -> pval=2.5693270562763505e-15
# test: pjnk and PKC given plcg, PIP3, PKA -> pval=2.8822606095345842e-15
# test: pjnk and PKC given plcg, PIP3, P38 -> pval=1.42212123789302e-17
# test: pjnk and PKC given plcg, perk, pakts473 -> pval=2.39891054412747e-15
# test: pjnk and PKC given plcg, perk, PKA -> pval=3.146849225888506e-15
# test: pjnk and PKC given plcg, perk, P38 -> pval=2.188639218809405e-17
# test: pjnk and PKC given plcg, pakts473, PKA -> pval=3.188980194340264e-15
# test: pjnk and PKC given plcg, pakts473, P38 -> pval=1.824403485786214e-17
# test: pjnk and PKC given plcg, PKA, P38 -> pval=1.831802027510963e-17
# test: pjnk and PKC given PIP2, PIP3, perk -> pval=2.3240108128317073e-15
# test: pjnk and PKC given PIP2, PIP3, pakts473 -> pval=2.286297803375473e-15
# test: pjnk and PKC given PIP2, PIP3, PKA -> pval=2.616291099462867e-15
# test: pjnk and PKC given PIP2, PIP3, P38 -> pval=1.1594899796629884e-17
# test: pjnk and PKC given PIP2, perk, pakts473 -> pval=2.363944123113269e-15
# test: pjnk and PKC given PIP2, perk, PKA -> pval=3.1280090988205373e-15
# test: pjnk and PKC given PIP2, perk, P38 -> pval=2.0365439195044413e-17
# test: pjnk and PKC given PIP2, pakts473, PKA -> pval=3.145021697652917e-15
# test: pjnk and PKC given PIP2, pakts473, P38 -> pval=1.6974465288998686e-17
# test: pjnk and PKC given PIP2, PKA, P38 -> pval=1.7450815612409253e-17
# test: pjnk and PKC given PIP3, perk, pakts473 -> pval=2.048937084146571e-15
# test: pjnk and PKC given PIP3, perk, PKA -> pval=2.7295290923832393e-15
# test: pjnk and PKC given PIP3, perk, P38 -> pval=1.705181282210617e-17
# test: pjnk and PKC given PIP3, pakts473, PKA -> pval=2.736796123424688e-15
# test: pjnk and PKC given PIP3, pakts473, P38 -> pval=1.4301921609778362e-17
# test: pjnk and PKC given PIP3, PKA, P38 -> pval=1.474868351200364e-17
# test: pjnk and PKC given perk, pakts473, PKA -> pval=2.6603486659633756e-15
# test: pjnk and PKC given perk, pakts473, P38 -> pval=1.962250680115277e-17
# test: pjnk and PKC given perk, PKA, P38 -> pval=2.042474437264943e-17
# test: pjnk and PKC given pakts473, PKA, P38 -> pval=1.7347702136245028e-17
# test: pjnk and P38 given praf, pmek, plcg -> pval=0.014723973165991448
# test: pjnk and P38 given praf, pmek, PIP2 -> pval=0.014838286174017572
# test: pjnk and P38 given praf, pmek, PIP3 -> pval=0.014685363794647592
# test: pjnk and P38 given praf, pmek, perk -> pval=0.014024697417274204
# test: pjnk and P38 given praf, pmek, pakts473 -> pval=0.014864750128311224
# test: pjnk and P38 given praf, pmek, PKA -> pval=0.015968861415243982
# test: pjnk and P38 given praf, pmek, PKC -> pval=5.009126045453303e-05
# test: pjnk and P38 given praf, plcg, PIP2 -> pval=0.0153376097479522
# test: pjnk and P38 given praf, plcg, PIP3 -> pval=0.015224997330828586
# test: pjnk and P38 given praf, plcg, perk -> pval=0.014236102505052237
# test: pjnk and P38 given praf, plcg, pakts473 -> pval=0.015258838146766119
# test: pjnk and P38 given praf, plcg, PKA -> pval=0.016365644213159638
# test: pjnk and P38 given praf, plcg, PKC -> pval=6.0584385140598e-05
# test: pjnk and P38 given praf, PIP2, PIP3 -> pval=0.015395987052616892
# test: pjnk and P38 given praf, PIP2, perk -> pval=0.014442551087169039
# test: pjnk and P38 given praf, PIP2, pakts473 -> pval=0.015432115454989851
# test: pjnk and P38 given praf, PIP2, PKA -> pval=0.01656656835421534
# test: pjnk and P38 given praf, PIP2, PKC -> pval=5.802471783441373e-05
# test: pjnk and P38 given praf, PIP3, perk -> pval=0.014366029961586575
# test: pjnk and P38 given praf, PIP3, pakts473 -> pval=0.0153045358236184
# test: pjnk and P38 given praf, PIP3, PKA -> pval=0.016417065975007424
# test: pjnk and P38 given praf, PIP3, PKC -> pval=5.6223066275232244e-05
# test: pjnk and P38 given praf, perk, pakts473 -> pval=0.013581561658271108
# test: pjnk and P38 given praf, perk, PKA -> pval=0.015454456355001806
# test: pjnk and P38 given praf, perk, PKC -> pval=6.758644571024108e-05
# test: pjnk and P38 given praf, pakts473, PKA -> pval=0.016501893298374794
# test: pjnk and P38 given praf, pakts473, PKC -> pval=6.010304072365366e-05
# test: pjnk and P38 given praf, PKA, PKC -> pval=5.734760724127022e-05
# test: pjnk and P38 given pmek, plcg, PIP2 -> pval=0.012112428782702548
# test: pjnk and P38 given pmek, plcg, PIP3 -> pval=0.01199042358065422
# test: pjnk and P38 given pmek, plcg, perk -> pval=0.011312257940859416
# test: pjnk and P38 given pmek, plcg, pakts473 -> pval=0.012092424497992183
# test: pjnk and P38 given pmek, plcg, PKA -> pval=0.012967200420215331
# test: pjnk and P38 given pmek, plcg, PKC -> pval=7.142390292002335e-05
# test: pjnk and P38 given pmek, PIP2, PIP3 -> pval=0.01207772490278287
# test: pjnk and P38 given pmek, PIP2, perk -> pval=0.01140674273445179
# test: pjnk and P38 given pmek, PIP2, pakts473 -> pval=0.01215994544651861
# test: pjnk and P38 given pmek, PIP2, PKA -> pval=0.01305603432633318
# test: pjnk and P38 given pmek, PIP2, PKC -> pval=6.919445153738821e-05
# test: pjnk and P38 given pmek, PIP3, perk -> pval=0.011322112473800043
# test: pjnk and P38 given pmek, PIP3, pakts473 -> pval=0.012026633692532667
# test: pjnk and P38 given pmek, PIP3, PKA -> pval=0.012902318069651725
# test: pjnk and P38 given pmek, PIP3, PKC -> pval=6.629027958689871e-05
# test: pjnk and P38 given pmek, perk, pakts473 -> pval=0.01085260530399514
# test: pjnk and P38 given pmek, perk, PKA -> pval=0.012257488539980545
# test: pjnk and P38 given pmek, perk, PKC -> pval=7.92954388039324e-05
# test: pjnk and P38 given pmek, pakts473, PKA -> pval=0.013026003274803634
# test: pjnk and P38 given pmek, pakts473, PKC -> pval=7.127654850761923e-05
# test: pjnk and P38 given pmek, PKA, PKC -> pval=6.79288824966464e-05
# test: pjnk and P38 given plcg, PIP2, PIP3 -> pval=0.01425350534846804
# test: pjnk and P38 given plcg, PIP2, perk -> pval=0.013268152647860345
# test: pjnk and P38 given plcg, PIP2, pakts473 -> pval=0.01425178174769675
# test: pjnk and P38 given plcg, PIP2, PKA -> pval=0.015243726837055577
# test: pjnk and P38 given plcg, PIP2, PKC -> pval=6.238178704566283e-05
# test: pjnk and P38 given plcg, PIP3, perk -> pval=0.013236793134958982
# test: pjnk and P38 given plcg, PIP3, pakts473 -> pval=0.014185424473309312
# test: pjnk and P38 given plcg, PIP3, PKA -> pval=0.01516869360035618
# test: pjnk and P38 given plcg, PIP3, PKC -> pval=6.152638330152745e-05
# test: pjnk and P38 given plcg, perk, pakts473 -> pval=0.012378267836924398
# test: pjnk and P38 given plcg, perk, PKA -> pval=0.014076185839494012
# test: pjnk and P38 given plcg, perk, PKC -> pval=7.462905386533661e-05
# test: pjnk and P38 given plcg, pakts473, PKA -> pval=0.015110616852801325
# test: pjnk and P38 given plcg, pakts473, PKC -> pval=6.593866267754748e-05
# test: pjnk and P38 given plcg, PKA, PKC -> pval=6.265902677141928e-05
# test: pjnk and P38 given PIP2, PIP3, perk -> pval=0.013387947053463467
# test: pjnk and P38 given PIP2, PIP3, pakts473 -> pval=0.014288176661068965
# test: pjnk and P38 given PIP2, PIP3, PKA -> pval=0.01529306767441199
# test: pjnk and P38 given PIP2, PIP3, PKC -> pval=5.5983603423498536e-05
# test: pjnk and P38 given PIP2, perk, pakts473 -> pval=0.012489007132345615
# test: pjnk and P38 given PIP2, perk, PKA -> pval=0.014269843074902732
# test: pjnk and P38 given PIP2, perk, PKC -> pval=7.127888440416833e-05
# test: pjnk and P38 given PIP2, pakts473, PKA -> pval=0.01525180568413358
# test: pjnk and P38 given PIP2, pakts473, PKC -> pval=6.323569961304469e-05
# test: pjnk and P38 given PIP2, PKA, PKC -> pval=6.047750556281348e-05
# test: pjnk and P38 given PIP3, perk, pakts473 -> pval=0.012467791797506103
# test: pjnk and P38 given PIP3, perk, PKA -> pval=0.014250004272513066
# test: pjnk and P38 given PIP3, perk, PKC -> pval=6.81331008792114e-05
# test: pjnk and P38 given PIP3, pakts473, PKA -> pval=0.015184773496818429
# test: pjnk and P38 given PIP3, pakts473, PKC -> pval=6.0729917127743074e-05
# test: pjnk and P38 given PIP3, PKA, PKC -> pval=5.817960371680611e-05
# test: pjnk and P38 given perk, pakts473, PKA -> pval=0.01337820133091064
# test: pjnk and P38 given perk, pakts473, PKC -> pval=7.753189491724744e-05
# test: pjnk and P38 given perk, PKA, PKC -> pval=6.822732910005536e-05
# test: pjnk and P38 given pakts473, PKA, PKC -> pval=6.06067142390392e-05

# %% [markdown]
# Now let's look at what else is in the dataset: the interventional data corresponding to different experiments. The PC algorithm did not look at this part of the dataset, but these additional experiments can obviously provide valuable information about the causal graph. In the following questions, we will investigate two examples of this. We will use the output of the PC algorithm to give us a rough idea of what the causal graph might look like.
#
# The interventions in these experiment are not perfect interventions: they change the structural equation of a variable, but not by setting it to a constant. The new structural equation in the intervened model may still include all variables that were there in the original model. So in the graph of the intervened model, all arrows will still be there.
#
# Further, some of the interventions change not one, but multiple structural equations.
#
# For some of the interventions in the data, here is what they do according to many (but not all) experts:
# * experiment 5 adds the substance psitectorigenin, which modifies the amount of PIP2;
# * experiment 6 adds the substance U0126, which increases the *activity* of pmek. This means that the amount of pmek is not changed by the intervention, but for all *children* of pmek in the causal model, the structural equation changes to reflect that pmek now has a stronger effect on them. pmek is believed to have only one child in the true causal model, namely perk.
#
# (Source: Mooij et al., 2019, specifically Tables 2 & 3 and Figure 35(a))

# %% [markdown]
# Create two new dataframes, one containing all data from experiments 1 and 5, and one with the data from experiments 1 and 6. These dataframes should still have an 'experiment' column, so that you can tell for each row whether it came from the observational or the interventional dataset.

# %%
exp1_5 = all_data.copy()

# Get names of indexes for which column experiment has not value 1,5
indexNames = exp1_5[ (exp1_5['experiment'] != 1) & (exp1_5['experiment'] != 5) ].index

# Delete these row indexes from dataFrame
exp1_5.drop(indexNames , inplace=True)

exp1_5
# Out:
#           praf      pmek      plcg  ...       P38      pjnk  experiment
# 0     3.594569  3.144152  2.934920  ...  4.005513  3.912023           1
# 1     3.826465  3.277145  3.104587  ...  3.277145  4.269697           1
# 2     4.239887  3.990834  3.202746  ...  3.735286  3.384390           1
# 3     4.418841  4.530447  3.499533  ...  3.653252  3.499533           1
# 4     3.777348  3.394508  2.720637  ...  3.575151  4.514151           1
# ...        ...       ...       ...  ...       ...       ...         ...
# 4194  4.262680  3.931826  2.636196  ...  4.371976  3.804438           5
# 4195  4.387014  3.543854  2.397895  ...  3.091042  3.770459           5
# 4196  4.284965  3.499533  2.590767  ...  3.693867  2.595255           5
# 4197  4.812184  4.418841  2.397895  ...  4.498698  3.983413           5
# 4198  4.619073  3.555348  2.662355  ...  3.797734  5.220356           5
#
# [1663 rows x 12 columns]

# %%
exp1_6 = all_data.copy()

# Get names of indexes for which column experiemnt has not value 1,6
indexNames = exp1_6[ (exp1_6['experiment'] != 1) & (exp1_6['experiment'] != 6) ].index

# Delete these row indexes from dataFrame
exp1_6.drop(indexNames , inplace=True)

exp1_6
# Out:
#           praf      pmek      plcg  ...       P38      pjnk  experiment
# 0     3.594569  3.144152  2.934920  ...  4.005513  3.912023           1
# 1     3.826465  3.277145  3.104587  ...  3.277145  4.269697           1
# 2     4.239887  3.990834  3.202746  ...  3.735286  3.384390           1
# 3     4.418841  4.530447  3.499533  ...  3.653252  3.499533           1
# 4     3.777348  3.394508  2.720637  ...  3.575151  4.514151           1
# ...        ...       ...       ...  ...       ...       ...         ...
# 4993  4.216562  4.619073  3.303217  ...  3.407842  2.673459           6
# 4994  5.874931  6.403574  3.246491  ...  3.742420  2.662355           6
# 4995  4.859812  5.117994  3.157000  ...  3.668677  3.881564           6
# 4996  5.459586  5.899897  3.273364  ...  4.546481  4.036009           6
# 4997  4.795791  5.056246  2.623944  ...  3.394508  2.548664           6
#
# [1652 rows x 12 columns]

# %% [markdown]
# **Question (1.5 points)**: In the dataframe for experiments 1 and 5, look at PIP2 and a variable adjacent to it in the output of PC (if there is more than one, pick one). Using about 200 words, answer the following questions: Based on looking at one or more plots (like scatterplots or histograms), which do you find more likely: that psitectorigenin directly modifies PIP2, or the neighbouring variable, or both? And what does the data for the two experiments seem to say about the direction of the arrow between PIP2 and its neighbour?
#
# Insert one or more markdown and code boxes below here to give your answer and the plots you base your answer on. (Please put your answer in markdown boxes, not as comments in your code!)

# %%
import matplotlib.pyplot as plt

variables = ['PIP2', 'PIP3']
exp_1 = exp1_5.loc[exp1_5['experiment'] == 1][variables]
exp_5 = exp1_5.loc[exp1_5['experiment'] == 5][variables]

exp1_mean = [exp_1[l].mean() for l in variables]
exp5_mean = [exp_5[l].mean() for l in variables]

fig, ax = plt.subplots()

x = np.arange(len(variables))
width = 0.35
hist1 = ax.bar(x - width/2, exp1_mean, width, label='observational')
hist2 = ax.bar(x + width/2, exp5_mean, width, label='psitectorigenin')

plt.xticks(x,variables)
plt.legend((hist1[0], hist2[0]), ('observational', 'psitectorigenin'))
ax.set_ylabel('mean protein value')

plt.show()

# %% [markdown]
# From the figure, the amount of PIP2 significantly decreased after adding the psitectorigenin, and the amount of PIP3 slightly decreased. The decrease in PIP2 demonstrates that pistectorigenin modifies the amount of PIP2. And according to the PC graph, the one-way arrow from PIP2 to PIP3 could explain that the drop of PIP3 is due to the drop of PIP2. So its more likely that the psitectorigenin directly modifies PIP2, and PIP2 influence the PIP3.

# %% [markdown]
# **Question (1.5 points)**: In the dataframe for experiments 1 and 6, look at pmek, perk, and any other variables adjacent to pmek in the output of PC. Assume it is true that adding U0126 produces an intervention on the *activity* of pmek. What would you expect to see in the data if the graph found by PC was correct? Would you propose any changes to that graph based on the data?
#
# Again put your answer (about 200 words) with accompanying plots in new boxes below here.

# %%
variables = ['pmek', 'perk', 'pjnk', 'praf','PIP3']
exp_1s = exp1_6.loc[exp1_6['experiment'] == 1][variables]
exp_6 = exp1_6.loc[exp1_6['experiment'] == 6][variables]

exp1s_mean = [exp_1s[l].mean() for l in variables]
exp6_mean = [exp_6[l].mean() for l in variables]

fig, ax = plt.subplots()

x = np.arange(len(variables))
width = 0.35
hist1 = ax.bar(x - width/2, exp1s_mean, width, label='observational')
hist2 = ax.bar(x + width/2, exp6_mean, width, label='U0126')

plt.xticks(x,variables)
plt.legend((hist1[0], hist2[0]), ('observational', 'U0126'))
ax.set_ylabel('mean protein value')

plt.show()

# %% [markdown]
# Assuming it's true that adding U0126 produces an intervention on the activity of pmek, and do not change the amount of pmek, if the graph found by PC was correct, that pemk does not have any child, we would expect to see that the amount of pmek unchanged before and after. According to the plot, a possible explain could be the activity of pmek has an effect on the amount of pjnk and praf, then both of which affect the amount of pemk according to the existing arrows in PC graph. So we should add arrows from pmek to praf and pjnk. And the plot can also prove the belief that pmek has a child perk, which should add an arrow for that. PIP3 stays constant, so no need to change.

# %% [markdown]
# ---
#
# You are almost done! Before handing in, make sure that the code you hand in works, and that all plots are shown. **Submit just one file per team.** Name the submitted file according to your and your collaborator's last name (`submitter_collaborator.ipynb`).

# %% [markdown]
# ### References
# * J. M. Mooij, S. Magliacane, and T. Claassen, "Joint Causal Inference from Multiple Contexts," [arXiv:1611.10351v4](https://arxiv.org/abs/1611.10351), 2019.
# * J. Runge, "Conditional Independence Testing Based on a Nearest-Neighbor Estimator of Conditional Mutual Information" In Proceedings of the 21st International Conference on Artificial Intelligence and Statistics, http://proceedings.mlr.press/v84/runge18a.html, 2018.
# * K. Sachs, O. Perez, D. Pe’er, D. A. Lauffenburger, and G. P. Nolan, "Causal protein-signaling networks derived from multiparameter single-cell data," Science, vol. 308, no. 5721, pp. 523–529, 2005.
